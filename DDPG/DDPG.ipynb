# %% [markdown]
# We first install and import necessary packages.

# %%
# !pip install torch
# !pip install swig
# !pip install gymnasium
# !pip install gymnasium[box2d]
# !pip install stable-baselines3

# %%
import gymnasium as gym

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as functional

import matplotlib.pyplot as plt

# %% [markdown]
# ## Lunar Lander
#
# Next, we instantiate the [Lunar Lander environment](https://www.gymlibrary.dev/environments/box2d/lunar_lander/) from OpenAI Gym and gain a quick understanding of its key variables and methods.
#
# The Lunar Lander environment models a rocket that needs to land on the moon. Follow the hyperlinks to learn more about the envionment [Acrobot environment](https://www.gymlibrary.dev/environments/box2d/lunar_lander/). In this assignment, we will use the Continuous (v2) version of the environment in which both the state and action spaces are continuous.
#
# ![](https://www.gymlibrary.dev/_images/lunar_lander.gif)

# %%
env = gym.make("LunarLanderContinuous-v2")
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.

# %% [markdown]
# #### States
#
# OpenAI Gym environments do not explicitly provide state but instead provide observation. In the Lunar Lander environment, the state and observation are identical. The state of the Lander is a 8-dimensional vector: the coordinates of the lander in x and y, its linear velocities in x and y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not.

# %%
print(f"Number of state features: {env.observation_space.shape[0]}")
# Out:
# Number of state features: 8

# %% [markdown]
# #### Actions
#
# The action space is also continous and includes two features. The first coordinate of an action determines the throttle of the main engine, while the second coordinate specifies the throttle of the lateral boosters.
#
# Given an action `np.array([main, lateral])`, the main engine will be turned off completely if `main < 0` and the throttle scales affinely from 50% to 100% for `0 <= main <= 1` (i.e., the main engine doesn’t work with less than 50% power). Similarly, if `-0.5 < lateral < 0.5`, the lateral boosters will not fire at all. If `lateral < -0.5`, the left booster will fire, and if `lateral > 0.5`, the right booster will fire. Again, the throttle scales affinely from 50% to 100% between -1 and -0.5 (and 0.5 and 1, respectively)

# %%
print(f"Number of action features: {env.action_space.shape[0]}")
# Out:
# Number of action features: 2

# %% [markdown]
# #### Transition and Reward Function
#
# The transition and rewards functions for the environment are not explicitly represented as matrices or tensors. Instead the gym API provides access to the `step` method, which takes in as input an `action` and provides (among other things) an `observation` and `reward`. Also notice the `reset` method, which resets the MDP environment.
#
# The following snippet describes the use of `step` and `reset` methods.

# %%
# Reset the environment
next_state = env.reset()
print(f"State: {next_state}")

# Select a random action to play
next_action = env.action_space.sample()
print(f"Action: {next_action}")

# Send this action to the environment to receive the next state and reward
next_state, reward, done, _, _ = env.step(next_action)
print(f"Next state: {next_state}")
print(f"Reward: {reward}")
# Out:
# State: (array([ 0.00640554,  1.416049  ,  0.6487917 ,  0.22793525, -0.00741558,
#        -0.14696087,  0.        ,  0.        ], dtype=float32), {})
# Action: [-0.19188674  0.02826439]
# Next state: [ 0.01281128  1.4206004   0.6479144   0.20223632 -0.01467745 -0.14525
#   0.          0.        ]
# Reward: -0.29336092275366354

# %%
observation_n = env.observation_space.shape[0]
action_n = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

observation_n, action_n, max_action
# Out:
# (8, 2, 1.0)

# %% [markdown]
# ## Point 1.1
#
# Next, we will implement the general recipe of the DDPG algorithm to compute the optimal policy for the Lunar Lander.

# %% [markdown]
# #### Actor-Critic Networks
#
# DDPG requires two networks: Actor and Critic. Let us know define these networks.

# %%
class Actor(nn.Module):
  """Actor Network as a Multi-Layer Perceptron."""

  def __init__(self, env, mlp_sizes=[256, 256]):
    """Initialize the Actor Network.

    Args:
        env: An OpenAI Gym environment.
        mlp_sizes: An array of integers. The length of array equals the number
            of hidden layers of the Multi-Layer Perceptron. Each element in the array
            equals the number of nodes in the corresponding layer.
    """
    super().__init__()

    observation_n = env.observation_space.shape[0]
    action_n = env.action_space.shape[0]

    # input layer
    self.input_layer = nn.Linear(observation_n, mlp_sizes[0])

    # hidden layers
    self.hidden_layers = nn.ModuleList()
    for k in range(len(mlp_sizes) - 1):
        self.hidden_layers.append(nn.Linear(mlp_sizes[k], mlp_sizes[k + 1]))

    # output layer
    self.output_layer = nn.Linear(mlp_sizes[-1], action_n)
    

  def forward(self, x):
    """Implements the forward pass of the Actor Network.

    Args:
        x: Input to the Actor Network.

    Returns:
        Output of the Actor Network.
    """

    max_action = float(env.action_space.high[0])

    x = functional.relu(self.input_layer(x))
    for hidden_layer in self.hidden_layers:
        x = functional.relu(hidden_layer(x))
    x = max_action * functional.tanh(self.output_layer(x))
    return x

# %%
class Critic(nn.Module):
  """Critic Network as a Multi-Layer Perceptron."""

  def __init__(self, env, mlp_sizes=[256, 256]):
    """Initialize the Critic Network.

    Args:
        env: An OpenAI Gym environment.
        mlp_sizes: An array of integers. The length of array equals the number
            of hidden layers of the Multi-Layer Perceptron. Each element in the array
            equals the number of nodes in the corresponding layer.
    """
    super().__init__()

    observation_n = env.observation_space.shape[0]
    action_n = env.action_space.shape[0]
    n_critic = 1

    # input layer
    self.input_layer = nn.Linear(observation_n + action_n, mlp_sizes[0])

    # hidden layers
    self.hidden_layers = nn.ModuleList()
    for k in range(len(mlp_sizes) - 1):
        self.hidden_layers.append(nn.Linear(mlp_sizes[k], mlp_sizes[k + 1]))

    # output layer
    self.output_layer = nn.Linear(mlp_sizes[-1], n_critic)


  def forward(self, x):
    """Implements the forward pass of the Critic Network.

    Args:
        x: Input to the Critic Network.

    Returns:
        Output of the Critic Network.
    """

    x = functional.relu(self.input_layer(x))
    for hidden_layer in self.hidden_layers:
        x = functional.relu(hidden_layer(x))
    x = self.output_layer(x)
    return x

# %% [markdown]
# #### Replay Buffer
#
# DDPG requires a data structure to store the agent's experiences: Replay Buffer. Let us now define this data structure.

# %%
class ReplayBuffer:
  """A buffer to store agent's experiences."""

  def __init__(self, env, buffer_size):
    """Initialize a buffer to store agent's experiences.

    Args:
        env: An OpenAI Gym environment.
        buffer_size: An integer. The size of the buffer.
    """
    observation_n = env.observation_space.shape[0]
    action_n = env.action_space.shape[0]

    self.buffer_size = buffer_size
    self.observations = np.zeros((self.buffer_size, observation_n), dtype=np.float32)
    self.next_observations = np.zeros((self.buffer_size, observation_n), dtype=np.float32)
    self.actions = np.zeros((self.buffer_size, action_n), dtype=np.float32)
    self.rewards = np.zeros((self.buffer_size,), dtype=np.float32)
    self.dones = np.zeros((self.buffer_size,), dtype=np.float32)

    self.size = 0
    self.pos = 0

  def add(self, observation, next_observation, action, reward, done):
    """Add an experience to the buffer.

    Args:
        observation: the current environment state
        next_observation: the state after executing the action
        action: the action executed in the state
        reward: the reward received after executing the action
        done: Boolean denoting whether the task is completed.
    """
    self.observations[self.pos] = observation
    self.next_observations[self.pos] = next_observation
    self.actions[self.pos] = action
    self.rewards[self.pos] = reward
    self.dones[self.pos] = 1.0 if done else 0.0

    self.pos += 1
    if self.size < self.buffer_size:
      self.size += 1
    if self.pos == self.buffer_size:
      self.pos = 0

  def sample(self, batch_size):
    """Sample a mini-batch of experiences from the replay buffer.
    For ease of implementation, we sample with replacement.

    Args:
        batch_size: An integer. The size of the mini-batch.

    Returns:
        Randomly sampled experiences from the replay buffer.
    """
    indices = np.random.randint(self.size, size=batch_size)
    observations = torch.from_numpy(self.observations[indices])
    next_observations = torch.from_numpy(self.next_observations[indices])
    actions = torch.from_numpy(self.actions[indices])
    rewards = torch.from_numpy(self.rewards[indices])
    dones = torch.from_numpy(self.dones[indices])

    return observations, next_observations, actions, rewards, dones

# %% [markdown]
# #### Exploration schedule
#
# In general, it is useful to explore more initially (when the agent is far from the optimal policy) and less later on in the learning process. To implement this, we can implement a schedule for epsilon.
#
# Similar to the Actor and Critic networks and replay buffer architectures, several choices exist for determining the epsilon schedule. We will use a simple linear scheduler to decay epsilon as agent gains more experience.

# %%
def linear_schedule_for_epsilon(initial_value, final_value, duration, timestep):
  """Implements a linear scheduler for epsilon.

  Args:
      initial_value: (float) Initial value of epsilon.
      final_value: (float) Final value of epsilon.
      duration: (int) Duration over which to decay epsilon from its initial to final value.
      timestep: (int) The current time step.

  Returns:
      Value of epsilon at the given timestep.
  """
  slope = (final_value - initial_value) / duration
  return max(slope * timestep + initial_value, final_value)

# %% [markdown]
# #### Target Networks
# In DDPG, we will update the target network in each iteration of the algorithm. A utility function to update the weights of the target network is provided below.

# %%
def update_weights(src, target, tau=1.0):
  """Utility function to update the target network using Polyak averaging.

  Args:
    src: (target network) source network
    target: (neural network) target network
    tau: (float) Polyak factor
  """

  for target_param, param in zip(target.parameters(), src.parameters()):
    target_param.data.copy_(
        target_param.data * (1.0 - tau) + param.data * tau
    )

# %% [markdown]
# #### DDPG algorithm
#
# Now that we have all the building blocks, we will implement the DDPG algorithm.
#
# We will use the AgentBase class from Assignment 2 to help us with the implementation.

# %%
class AgentBase:
  def __init__(self, env):
    self.env = env
    self.policy = self.make_policy()
    self.behavior_policy = self.make_behavior_policy()

  def make_policy(self):
    """
    Return a policy function that will be used for evaluation. The policy
    takes observation as input and return action
    """
    raise NotImplementedError

  def make_behavior_policy(self):
    """
    Similar to make_policy, it returns a policy function. But this one used
    for interaction with the environment.
    """
    raise NotImplementedError

  def run_episode(self, episode_policy):
    """
    Generate one episode with the given policy
    """
    episode = []
    done = False
    obs = self.env.reset()[0]
    episode_return = 0
    while not done:
      action = episode_policy(obs)
      next_obs, reward, done, truncated, _ = self.env.step(action)
      done = done or truncated
      episode.append([obs, action, reward, next_obs, done])
      obs = next_obs
      episode_return += reward

    return (episode, episode_return)

  def evaluate(self, num_eval_episodes=1000, plot_title="Evaluation"):
    """Evaluates the agent."""
    list_returns = []
    list_average_returns = []
    average_return = 0
    for episode_idx in range(num_eval_episodes):
      _, episode_return = self.run_episode(self.policy)
      average_return += (1. / (episode_idx+1)) * (episode_return - average_return)
      list_returns.append(episode_return)
      list_average_returns.append(average_return)

    print(f"Average reward {round(average_return, 3)}")
    plt.plot(list_returns,'^',label="Return")
    plt.plot(list_average_returns,'r',label="Average Return")
    plt.ylabel('Return')
    plt.xlabel('Episode#')
    plt.title(plot_title)
    plt.legend()
    plt.ylim(-501, 0.0)
    plt.show()

# %%
class DDPG(AgentBase):
  """Implements DDPG."""

  def __init__(
      self,
      env,
      actor_lr=0.0002,
      critic_lr=0.0003,
      total_timesteps=500000,
      buffer_size=50000,
      warmup_steps=1000,
      batch_size=64,
      tau=0.005,
      noise_std=0.1,
  ):
      """Initializes the Agent.
      Args:
          env: An OpenAI Gym environment.
          actor_lr: (float) Learning rate of actor
          critic_lr: (float) Learning rate of critic
          total_timesteps: (integer) The number of timesteps in training
          buffer_size: (integer) Size of the replay buffer.
          warmup_steps: (integer) Size of data for pre-filling buffer
          batch_size: (integer) Size of the mini batch.
          tau: (float) The amount of update to target actor/critic
          noise_std: (float) Initial noise level for exploration.
      """
      super().__init__(env=env)

      self.gamma = 0.99 # Assume a discount factor of 0.99
      self.env = env
      self.actor_lr = actor_lr
      self.critic_lr = critic_lr
      self.total_timesteps = total_timesteps
      self.buffer_size = buffer_size
      self.warmup_steps = warmup_steps
      self.batch_size = batch_size
      self.tau = tau
      self.noise_std = noise_std

      # Create actor and critic

      self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

      self.actor = Actor(env=env).to(self.device)
      self.actor_target = Actor(env=env).to(self.device)
      self.critic = Critic(env=env).to(self.device)
      self.critic_target = Critic(env=env).to(self.device)


      # Copy weights to target networks
      update_weights(self.actor, self.actor_target)
      update_weights(self.critic, self.critic_target)

      # Create optimizers
      self.actor_optim = torch.optim.Adam(self.actor.parameters(), lr=actor_lr)
      self.critic_optim = torch.optim.Adam(self.critic.parameters(), lr=critic_lr)

      # Create replay buffer
      self.replay_buffer = ReplayBuffer(env=env, buffer_size=buffer_size)

      # Create variables for logging
      self.obs = env.reset()[0]
      self.current_step = 0
      self.list_returns = []
      self.list_average_returns = []
      self.average_return = 0.
      self.list_moving_average_returns = []

  def make_policy(self):
    def policy_func(observation):
      state = torch.from_numpy(observation).to(self.device)
      action_probs: torch.Tensor = self.actor(state)
      action = action_probs.detach().cpu().numpy()
      return action

    return policy_func

  def make_behavior_policy(self):
    def policy_func(observation):
      state = torch.from_numpy(observation).to(self.device)
      action_probs: torch.Tensor = self.actor(state)
      
      # refs: https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
      sigma = linear_schedule_for_epsilon(
        self.noise_std,
        self.noise_std * 0.1,
        self.total_timesteps * 0.9,
        self.current_step
      )
      mu = action_probs.detach().cpu().numpy()
      action = np.random \
        .normal(mu, sigma, env.action_space.shape) \
        .clip(env.action_space.low, env.action_space.high)

      return action

    return policy_func

  def update(self):
    if self.current_step > self.warmup_steps:

      # Sample a batch

      observations, next_observations, actions, rewards, dones = self.replay_buffer.sample(self.batch_size)
      observations = observations.to(self.device)
      next_observations = next_observations.to(self.device)
      actions = actions.to(self.device)
      rewards = rewards.to(self.device)
      dones = dones.to(self.device)

      # Get target values
      next_states = next_observations
      next_actions = self.actor_target(next_states)
      target_Q = self.critic_target(torch.cat([next_states, next_actions], dim=1)).view(-1)
      target_Q = rewards + self.gamma * target_Q * (1.0 - dones)
      target_Q = target_Q.detach().view(-1)

      # Decay learning rate
      # DO NOTHING

      # Update critic
      states = observations
      current_Q = self.critic(torch.cat([states, actions], dim=1)).view(-1)

      critic_loss = functional.mse_loss(current_Q, target_Q)

      self.critic_optim.zero_grad()
      critic_loss.backward()
      self.critic_optim.step()

      # Update actor
      another_states = observations
      another_actions = self.actor(another_states)
      another_Q = self.critic(torch.cat([another_states, another_actions], dim=1)).view(-1)
      
      actor_loss = -another_Q.mean()

      self.actor_optim.zero_grad()
      actor_loss.backward()
      self.actor_optim.step()

    # Update Target Network
    update_weights(self.actor, self.actor_target, self.tau)
    update_weights(self.critic, self.critic_target, self.tau)


  def train(self, make_plot=False):
    episode_return = 0.
    while self.current_step < self.total_timesteps:

      # Interact with env
      action = self.behavior_policy(self.obs)
      next_obs, reward, done, truncated, info = self.env.step(action)
      episode_return += reward
      done = done or truncated

      if done:
        # Store the return for evaluation
        self.list_returns.append(episode_return)
        episode_return = 0.
        self.average_return = np.mean(np.asarray(self.list_returns))
        self.list_average_returns.append(self.average_return)

        if len(self.list_average_returns) > 20:
          self.list_moving_average_returns.append(np.mean(self.list_returns[-20:]))
        else:
          self.list_moving_average_returns.append(self.average_return)

      # Save data into buffer
      self.replay_buffer.add(self.obs, next_obs, action, reward, done)

      # Update networks
      self.update()

      # Prepare for next iteration
      if done:
        self.obs = env.reset()[0]
      else:
        self.obs = next_obs

      if self.current_step % 1000 == 999:
        print(f"Timestep: {self.current_step+1}, episode reward (moving average, 20 episodes): {round(self.list_moving_average_returns[-1],2)}")
      self.current_step += 1

    if make_plot:
      plt.plot(self.list_returns,'^',label="Return")
      plt.plot(self.list_average_returns,'r',label="Average Return (all episodes)")
      plt.plot(self.list_moving_average_returns,'b',label="Average Return (last 20 episodes)")
      plt.ylabel('Return')
      plt.xlabel('Episode#')
      plt.title('Performance during training')
      plt.ylim(-501, 300)
      plt.legend()
      plt.show()

# %% [markdown]
# #### Training the Agent
#
# Having implemented the agent, now we will train it using the default hyperparameters provided in the class definition and observe its performance.

# %%
env = gym.make("LunarLanderContinuous-v2")

# %%
agent_001 = DDPG(env, total_timesteps=int(5e5))
agent_001.train(make_plot=True)
# Out:
# Timestep: 1000, episode reward (moving average, 20 episodes): -133.44
# Timestep: 2000, episode reward (moving average, 20 episodes): -200.41
# Timestep: 3000, episode reward (moving average, 20 episodes): -214.63
# Timestep: 4000, episode reward (moving average, 20 episodes): -180.81
# Timestep: 5000, episode reward (moving average, 20 episodes): -163.51
# Timestep: 6000, episode reward (moving average, 20 episodes): -151.35
# Timestep: 7000, episode reward (moving average, 20 episodes): -159.95
# Timestep: 8000, episode reward (moving average, 20 episodes): -158.04
# Timestep: 9000, episode reward (moving average, 20 episodes): -137.29
# Timestep: 10000, episode reward (moving average, 20 episodes): -142.7
# Timestep: 11000, episode reward (moving average, 20 episodes): -153.23
# Timestep: 12000, episode reward (moving average, 20 episodes): -154.13
# Timestep: 13000, episode reward (moving average, 20 episodes): -155.37
# Timestep: 14000, episode reward (moving average, 20 episodes): -158.42
# Timestep: 15000, episode reward (moving average, 20 episodes): -147.17
# Timestep: 16000, episode reward (moving average, 20 episodes): -158.59
# Timestep: 17000, episode reward (moving average, 20 episodes): -202.97
# Timestep: 18000, episode reward (moving average, 20 episodes): -246.98
# Timestep: 19000, episode reward (moving average, 20 episodes): -243.72
# Timestep: 20000, episode reward (moving average, 20 episodes): -255.08
# Timestep: 21000, episode reward (moving average, 20 episodes): -267.29
# Timestep: 22000, episode reward (moving average, 20 episodes): -269.5
# Timestep: 23000, episode reward (moving average, 20 episodes): -287.67
# Timestep: 24000, episode reward (moving average, 20 episodes): -298.88
# Timestep: 25000, episode reward (moving average, 20 episodes): -299.31
# Timestep: 26000, episode reward (moving average, 20 episodes): -293.6
# Timestep: 27000, episode reward (moving average, 20 episodes): -283.06
# Timestep: 28000, episode reward (moving average, 20 episodes): -275.15
# Timestep: 29000, episode reward (moving average, 20 episodes): -270.22
# Timestep: 30000, episode reward (moving average, 20 episodes): -244.62
# Timestep: 31000, episode reward (moving average, 20 episodes): -210.94
# Timestep: 32000, episode reward (moving average, 20 episodes): -203.04
# Timestep: 33000, episode reward (moving average, 20 episodes): -195.59
# Timestep: 34000, episode reward (moving average, 20 episodes): -168.16
# Timestep: 35000, episode reward (moving average, 20 episodes): -168.47
# Timestep: 36000, episode reward (moving average, 20 episodes): -168.14
# Timestep: 37000, episode reward (moving average, 20 episodes): -159.82
# Timestep: 38000, episode reward (moving average, 20 episodes): -156.47
# Timestep: 39000, episode reward (moving average, 20 episodes): -152.46
# Timestep: 40000, episode reward (moving average, 20 episodes): -123.03
# Timestep: 41000, episode reward (moving average, 20 episodes): -125.9
# Timestep: 42000, episode reward (moving average, 20 episodes): -129.67
# Timestep: 43000, episode reward (moving average, 20 episodes): -130.51
# Timestep: 44000, episode reward (moving average, 20 episodes): -133.71
# Timestep: 45000, episode reward (moving average, 20 episodes): -144.05
# Timestep: 46000, episode reward (moving average, 20 episodes): -146.46
# Timestep: 47000, episode reward (moving average, 20 episodes): -170.93
# Timestep: 48000, episode reward (moving average, 20 episodes): -194.26
# Timestep: 49000, episode reward (moving average, 20 episodes): -193.33
# Timestep: 50000, episode reward (moving average, 20 episodes): -196.29
# Timestep: 51000, episode reward (moving average, 20 episodes): -200.11
# Timestep: 52000, episode reward (moving average, 20 episodes): -205.71
# Timestep: 53000, episode reward (moving average, 20 episodes): -215.0
# Timestep: 54000, episode reward (moving average, 20 episodes): -214.4
# Timestep: 55000, episode reward (moving average, 20 episodes): -194.43
# Timestep: 56000, episode reward (moving average, 20 episodes): -190.33
# Timestep: 57000, episode reward (moving average, 20 episodes): -169.25
# Timestep: 58000, episode reward (moving average, 20 episodes): -136.7
# Timestep: 59000, episode reward (moving average, 20 episodes): -127.25
# Timestep: 60000, episode reward (moving average, 20 episodes): -120.28
# Timestep: 61000, episode reward (moving average, 20 episodes): -116.11
# Timestep: 62000, episode reward (moving average, 20 episodes): -117.05
# Timestep: 63000, episode reward (moving average, 20 episodes): -112.96
# Timestep: 64000, episode reward (moving average, 20 episodes): -109.86
# Timestep: 65000, episode reward (moving average, 20 episodes): -108.31
# Timestep: 66000, episode reward (moving average, 20 episodes): -102.51
# Timestep: 67000, episode reward (moving average, 20 episodes): -91.09
# Timestep: 68000, episode reward (moving average, 20 episodes): -89.06
# Timestep: 69000, episode reward (moving average, 20 episodes): -90.65
# Timestep: 70000, episode reward (moving average, 20 episodes): -105.26
# Timestep: 71000, episode reward (moving average, 20 episodes): -106.68
# Timestep: 72000, episode reward (moving average, 20 episodes): -105.9
# Timestep: 73000, episode reward (moving average, 20 episodes): -106.14
# Timestep: 74000, episode reward (moving average, 20 episodes): -111.27
# Timestep: 75000, episode reward (moving average, 20 episodes): -122.33
# Timestep: 76000, episode reward (moving average, 20 episodes): -127.03
# Timestep: 77000, episode reward (moving average, 20 episodes): -128.15
# Timestep: 78000, episode reward (moving average, 20 episodes): -123.8
# Timestep: 79000, episode reward (moving average, 20 episodes): -119.49
# Timestep: 80000, episode reward (moving average, 20 episodes): -117.56
# Timestep: 81000, episode reward (moving average, 20 episodes): -112.92
# Timestep: 82000, episode reward (moving average, 20 episodes): -113.74
# Timestep: 83000, episode reward (moving average, 20 episodes): -110.88
# Timestep: 84000, episode reward (moving average, 20 episodes): -116.5
# Timestep: 85000, episode reward (moving average, 20 episodes): -115.91
# Timestep: 86000, episode reward (moving average, 20 episodes): -115.3
# Timestep: 87000, episode reward (moving average, 20 episodes): -117.66
# Timestep: 88000, episode reward (moving average, 20 episodes): -105.64
# Timestep: 89000, episode reward (moving average, 20 episodes): -103.28
# Timestep: 90000, episode reward (moving average, 20 episodes): -106.77
# Timestep: 91000, episode reward (moving average, 20 episodes): -109.82
# Timestep: 92000, episode reward (moving average, 20 episodes): -115.31
# Timestep: 93000, episode reward (moving average, 20 episodes): -118.86
# Timestep: 94000, episode reward (moving average, 20 episodes): -129.82
# Timestep: 95000, episode reward (moving average, 20 episodes): -126.84
# Timestep: 96000, episode reward (moving average, 20 episodes): -133.55
# Timestep: 97000, episode reward (moving average, 20 episodes): -134.22
# Timestep: 98000, episode reward (moving average, 20 episodes): -131.71
# Timestep: 99000, episode reward (moving average, 20 episodes): -126.97
# Timestep: 100000, episode reward (moving average, 20 episodes): -127.34
# Timestep: 101000, episode reward (moving average, 20 episodes): -130.77
# Timestep: 102000, episode reward (moving average, 20 episodes): -128.86
# Timestep: 103000, episode reward (moving average, 20 episodes): -127.42
# Timestep: 104000, episode reward (moving average, 20 episodes): -128.52
# Timestep: 105000, episode reward (moving average, 20 episodes): -126.14
# Timestep: 106000, episode reward (moving average, 20 episodes): -126.81
# Timestep: 107000, episode reward (moving average, 20 episodes): -128.43
# Timestep: 108000, episode reward (moving average, 20 episodes): -113.73
# Timestep: 109000, episode reward (moving average, 20 episodes): -113.2
# Timestep: 110000, episode reward (moving average, 20 episodes): -112.75
# Timestep: 111000, episode reward (moving average, 20 episodes): -103.15
# Timestep: 112000, episode reward (moving average, 20 episodes): -107.45
# Timestep: 113000, episode reward (moving average, 20 episodes): -110.71
# Timestep: 114000, episode reward (moving average, 20 episodes): -112.39
# Timestep: 115000, episode reward (moving average, 20 episodes): -110.99
# Timestep: 116000, episode reward (moving average, 20 episodes): -112.17
# Timestep: 117000, episode reward (moving average, 20 episodes): -136.75
# Timestep: 118000, episode reward (moving average, 20 episodes): -155.26
# Timestep: 119000, episode reward (moving average, 20 episodes): -151.33
# Timestep: 120000, episode reward (moving average, 20 episodes): -145.05
# Timestep: 121000, episode reward (moving average, 20 episodes): -141.38
# Timestep: 122000, episode reward (moving average, 20 episodes): -135.97
# Timestep: 123000, episode reward (moving average, 20 episodes): -134.84
# Timestep: 124000, episode reward (moving average, 20 episodes): -130.5
# Timestep: 125000, episode reward (moving average, 20 episodes): -137.48
# Timestep: 126000, episode reward (moving average, 20 episodes): -148.49
# Timestep: 127000, episode reward (moving average, 20 episodes): -143.56
# Timestep: 128000, episode reward (moving average, 20 episodes): -138.02
# Timestep: 129000, episode reward (moving average, 20 episodes): -134.85
# Timestep: 130000, episode reward (moving average, 20 episodes): -132.52
# Timestep: 131000, episode reward (moving average, 20 episodes): -127.58
# Timestep: 132000, episode reward (moving average, 20 episodes): -121.9
# Timestep: 133000, episode reward (moving average, 20 episodes): -117.61
# Timestep: 134000, episode reward (moving average, 20 episodes): -88.36
# Timestep: 135000, episode reward (moving average, 20 episodes): -69.51
# Timestep: 136000, episode reward (moving average, 20 episodes): -72.86
# Timestep: 137000, episode reward (moving average, 20 episodes): -76.61
# Timestep: 138000, episode reward (moving average, 20 episodes): -78.74
# Timestep: 139000, episode reward (moving average, 20 episodes): -81.86
# Timestep: 140000, episode reward (moving average, 20 episodes): -78.68
# Timestep: 141000, episode reward (moving average, 20 episodes): -79.03
# Timestep: 142000, episode reward (moving average, 20 episodes): -66.82
# Timestep: 143000, episode reward (moving average, 20 episodes): -56.29
# Timestep: 144000, episode reward (moving average, 20 episodes): -46.59
# Timestep: 145000, episode reward (moving average, 20 episodes): -59.72
# Timestep: 146000, episode reward (moving average, 20 episodes): -70.24
# Timestep: 147000, episode reward (moving average, 20 episodes): -77.51
# Timestep: 148000, episode reward (moving average, 20 episodes): -119.14
# Timestep: 149000, episode reward (moving average, 20 episodes): -132.5
# Timestep: 150000, episode reward (moving average, 20 episodes): -128.54
# Timestep: 151000, episode reward (moving average, 20 episodes): -124.15
# Timestep: 152000, episode reward (moving average, 20 episodes): -118.04
# Timestep: 153000, episode reward (moving average, 20 episodes): -115.42
# Timestep: 154000, episode reward (moving average, 20 episodes): -112.08
# Timestep: 155000, episode reward (moving average, 20 episodes): -113.02
# Timestep: 156000, episode reward (moving average, 20 episodes): -116.26
# Timestep: 157000, episode reward (moving average, 20 episodes): -115.39
# Timestep: 158000, episode reward (moving average, 20 episodes): -116.93
# Timestep: 159000, episode reward (moving average, 20 episodes): -117.04
# Timestep: 160000, episode reward (moving average, 20 episodes): -113.73
# Timestep: 161000, episode reward (moving average, 20 episodes): -87.31
# Timestep: 162000, episode reward (moving average, 20 episodes): -86.99
# Timestep: 163000, episode reward (moving average, 20 episodes): -72.08
# Timestep: 164000, episode reward (moving average, 20 episodes): -38.51
# Timestep: 165000, episode reward (moving average, 20 episodes): -27.6
# Timestep: 166000, episode reward (moving average, 20 episodes): -29.27
# Timestep: 167000, episode reward (moving average, 20 episodes): -49.22
# Timestep: 168000, episode reward (moving average, 20 episodes): -79.02
# Timestep: 169000, episode reward (moving average, 20 episodes): -87.52
# Timestep: 170000, episode reward (moving average, 20 episodes): -105.41
# Timestep: 171000, episode reward (moving average, 20 episodes): -122.86
# Timestep: 172000, episode reward (moving average, 20 episodes): -140.74
# Timestep: 173000, episode reward (moving average, 20 episodes): -214.16
# Timestep: 174000, episode reward (moving average, 20 episodes): -221.9
# Timestep: 175000, episode reward (moving average, 20 episodes): -235.59
# Timestep: 176000, episode reward (moving average, 20 episodes): -243.49
# Timestep: 177000, episode reward (moving average, 20 episodes): -233.84
# Timestep: 178000, episode reward (moving average, 20 episodes): -229.02
# Timestep: 179000, episode reward (moving average, 20 episodes): -214.55
# Timestep: 180000, episode reward (moving average, 20 episodes): -216.14
# Timestep: 181000, episode reward (moving average, 20 episodes): -202.1
# Timestep: 182000, episode reward (moving average, 20 episodes): -185.31
# Timestep: 183000, episode reward (moving average, 20 episodes): -178.32
# Timestep: 184000, episode reward (moving average, 20 episodes): -166.3
# Timestep: 185000, episode reward (moving average, 20 episodes): -156.91
# Timestep: 186000, episode reward (moving average, 20 episodes): -110.07
# Timestep: 187000, episode reward (moving average, 20 episodes): -82.57
# Timestep: 188000, episode reward (moving average, 20 episodes): -79.99
# Timestep: 189000, episode reward (moving average, 20 episodes): -107.61
# Timestep: 190000, episode reward (moving average, 20 episodes): -105.52
# Timestep: 191000, episode reward (moving average, 20 episodes): -139.22
# Timestep: 192000, episode reward (moving average, 20 episodes): -142.02
# Timestep: 193000, episode reward (moving average, 20 episodes): -140.23
# Timestep: 194000, episode reward (moving average, 20 episodes): -144.41
# Timestep: 195000, episode reward (moving average, 20 episodes): -141.13
# Timestep: 196000, episode reward (moving average, 20 episodes): -127.06
# Timestep: 197000, episode reward (moving average, 20 episodes): -127.05
# Timestep: 198000, episode reward (moving average, 20 episodes): -126.43
# Timestep: 199000, episode reward (moving average, 20 episodes): -125.49
# Timestep: 200000, episode reward (moving average, 20 episodes): -130.2
# Timestep: 201000, episode reward (moving average, 20 episodes): -133.64
# Timestep: 202000, episode reward (moving average, 20 episodes): -134.94
# Timestep: 203000, episode reward (moving average, 20 episodes): -172.87
# Timestep: 204000, episode reward (moving average, 20 episodes): -168.45
# Timestep: 205000, episode reward (moving average, 20 episodes): -205.82
# Timestep: 206000, episode reward (moving average, 20 episodes): -164.28
# Timestep: 207000, episode reward (moving average, 20 episodes): -167.11
# Timestep: 208000, episode reward (moving average, 20 episodes): -162.83
# Timestep: 209000, episode reward (moving average, 20 episodes): -99.36
# Timestep: 210000, episode reward (moving average, 20 episodes): -104.95
# Timestep: 211000, episode reward (moving average, 20 episodes): -108.62
# Timestep: 212000, episode reward (moving average, 20 episodes): -110.11
# Timestep: 213000, episode reward (moving average, 20 episodes): -117.37
# Timestep: 214000, episode reward (moving average, 20 episodes): -116.63
# Timestep: 215000, episode reward (moving average, 20 episodes): -109.34
# Timestep: 216000, episode reward (moving average, 20 episodes): -106.88
# Timestep: 217000, episode reward (moving average, 20 episodes): -104.68
# Timestep: 218000, episode reward (moving average, 20 episodes): -121.5
# Timestep: 219000, episode reward (moving average, 20 episodes): -116.58
# Timestep: 220000, episode reward (moving average, 20 episodes): -120.44
# Timestep: 221000, episode reward (moving average, 20 episodes): -85.83
# Timestep: 222000, episode reward (moving average, 20 episodes): -89.72
# Timestep: 223000, episode reward (moving average, 20 episodes): -66.17
# Timestep: 224000, episode reward (moving average, 20 episodes): -39.5
# Timestep: 225000, episode reward (moving average, 20 episodes): -86.26
# Timestep: 226000, episode reward (moving average, 20 episodes): -85.08
# Timestep: 227000, episode reward (moving average, 20 episodes): -111.11
# Timestep: 228000, episode reward (moving average, 20 episodes): -108.42
# Timestep: 229000, episode reward (moving average, 20 episodes): -111.57
# Timestep: 230000, episode reward (moving average, 20 episodes): -114.98
# Timestep: 231000, episode reward (moving average, 20 episodes): -118.58
# Timestep: 232000, episode reward (moving average, 20 episodes): -148.44
# Timestep: 233000, episode reward (moving average, 20 episodes): -163.69
# Timestep: 234000, episode reward (moving average, 20 episodes): -152.47
# Timestep: 235000, episode reward (moving average, 20 episodes): -83.93
# Timestep: 236000, episode reward (moving average, 20 episodes): -66.45
# Timestep: 237000, episode reward (moving average, 20 episodes): -22.34
# Timestep: 238000, episode reward (moving average, 20 episodes): 3.17
# Timestep: 239000, episode reward (moving average, 20 episodes): 52.62
# Timestep: 240000, episode reward (moving average, 20 episodes): 90.01
# Timestep: 241000, episode reward (moving average, 20 episodes): 108.17
# Timestep: 242000, episode reward (moving average, 20 episodes): 125.67
# Timestep: 243000, episode reward (moving average, 20 episodes): 108.02
# Timestep: 244000, episode reward (moving average, 20 episodes): 83.82
# Timestep: 245000, episode reward (moving average, 20 episodes): 91.72
# Timestep: 246000, episode reward (moving average, 20 episodes): 97.77
# Timestep: 247000, episode reward (moving average, 20 episodes): 8.43
# Timestep: 248000, episode reward (moving average, 20 episodes): -18.84
# Timestep: 249000, episode reward (moving average, 20 episodes): -29.23
# Timestep: 250000, episode reward (moving average, 20 episodes): -53.94
# Timestep: 251000, episode reward (moving average, 20 episodes): -70.66
# Timestep: 252000, episode reward (moving average, 20 episodes): -79.09
# Timestep: 253000, episode reward (moving average, 20 episodes): -45.04
# Timestep: 254000, episode reward (moving average, 20 episodes): -58.16
# Timestep: 255000, episode reward (moving average, 20 episodes): -69.58
# Timestep: 256000, episode reward (moving average, 20 episodes): -71.05
# Timestep: 257000, episode reward (moving average, 20 episodes): -86.23
# Timestep: 258000, episode reward (moving average, 20 episodes): -82.32
# Timestep: 259000, episode reward (moving average, 20 episodes): -81.1
# Timestep: 260000, episode reward (moving average, 20 episodes): -78.03
# Timestep: 261000, episode reward (moving average, 20 episodes): -69.68
# Timestep: 262000, episode reward (moving average, 20 episodes): -81.44
# Timestep: 263000, episode reward (moving average, 20 episodes): -72.18
# Timestep: 264000, episode reward (moving average, 20 episodes): -69.97
# Timestep: 265000, episode reward (moving average, 20 episodes): -75.09
# Timestep: 266000, episode reward (moving average, 20 episodes): -58.17
# Timestep: 267000, episode reward (moving average, 20 episodes): -54.82
# Timestep: 268000, episode reward (moving average, 20 episodes): -52.21
# Timestep: 269000, episode reward (moving average, 20 episodes): -63.95
# Timestep: 270000, episode reward (moving average, 20 episodes): -83.3
# Timestep: 271000, episode reward (moving average, 20 episodes): -81.47
# Timestep: 272000, episode reward (moving average, 20 episodes): -73.93
# Timestep: 273000, episode reward (moving average, 20 episodes): -66.27
# Timestep: 274000, episode reward (moving average, 20 episodes): -31.31
# Timestep: 275000, episode reward (moving average, 20 episodes): -50.3
# Timestep: 276000, episode reward (moving average, 20 episodes): -51.4
# Timestep: 277000, episode reward (moving average, 20 episodes): -39.87
# Timestep: 278000, episode reward (moving average, 20 episodes): -58.36
# Timestep: 279000, episode reward (moving average, 20 episodes): -30.17
# Timestep: 280000, episode reward (moving average, 20 episodes): 24.06
# Timestep: 281000, episode reward (moving average, 20 episodes): 30.22
# Timestep: 282000, episode reward (moving average, 20 episodes): 24.9
# Timestep: 283000, episode reward (moving average, 20 episodes): 11.87
# Timestep: 284000, episode reward (moving average, 20 episodes): 8.01
# Timestep: 285000, episode reward (moving average, 20 episodes): 7.45
# Timestep: 286000, episode reward (moving average, 20 episodes): 4.54
# Timestep: 287000, episode reward (moving average, 20 episodes): 9.0
# Timestep: 288000, episode reward (moving average, 20 episodes): 18.47
# Timestep: 289000, episode reward (moving average, 20 episodes): 23.26
# Timestep: 290000, episode reward (moving average, 20 episodes): 10.8
# Timestep: 291000, episode reward (moving average, 20 episodes): -16.13
# Timestep: 292000, episode reward (moving average, 20 episodes): -4.1
# Timestep: 293000, episode reward (moving average, 20 episodes): 1.45
# Timestep: 294000, episode reward (moving average, 20 episodes): 16.87
# Timestep: 295000, episode reward (moving average, 20 episodes): 26.13
# Timestep: 296000, episode reward (moving average, 20 episodes): 35.26
# Timestep: 297000, episode reward (moving average, 20 episodes): 33.7
# Timestep: 298000, episode reward (moving average, 20 episodes): 37.04
# Timestep: 299000, episode reward (moving average, 20 episodes): 38.49
# Timestep: 300000, episode reward (moving average, 20 episodes): 18.95
# Timestep: 301000, episode reward (moving average, 20 episodes): 21.13
# Timestep: 302000, episode reward (moving average, 20 episodes): -7.93
# Timestep: 303000, episode reward (moving average, 20 episodes): -21.49
# Timestep: 304000, episode reward (moving average, 20 episodes): -24.65
# Timestep: 305000, episode reward (moving average, 20 episodes): -37.83
# Timestep: 306000, episode reward (moving average, 20 episodes): -52.48
# Timestep: 307000, episode reward (moving average, 20 episodes): -69.83
# Timestep: 308000, episode reward (moving average, 20 episodes): -59.61
# Timestep: 309000, episode reward (moving average, 20 episodes): -57.19
# Timestep: 310000, episode reward (moving average, 20 episodes): -42.14
# Timestep: 311000, episode reward (moving average, 20 episodes): -25.8
# Timestep: 312000, episode reward (moving average, 20 episodes): -48.04
# Timestep: 313000, episode reward (moving average, 20 episodes): -39.57
# Timestep: 314000, episode reward (moving average, 20 episodes): -42.59
# Timestep: 315000, episode reward (moving average, 20 episodes): -38.87
# Timestep: 316000, episode reward (moving average, 20 episodes): -42.04
# Timestep: 317000, episode reward (moving average, 20 episodes): -16.04
# Timestep: 318000, episode reward (moving average, 20 episodes): -14.49
# Timestep: 319000, episode reward (moving average, 20 episodes): -8.55
# Timestep: 320000, episode reward (moving average, 20 episodes): 0.42
# Timestep: 321000, episode reward (moving average, 20 episodes): 12.35
# Timestep: 322000, episode reward (moving average, 20 episodes): -2.65
# Timestep: 323000, episode reward (moving average, 20 episodes): -22.25
# Timestep: 324000, episode reward (moving average, 20 episodes): -33.97
# Timestep: 325000, episode reward (moving average, 20 episodes): -46.57
# Timestep: 326000, episode reward (moving average, 20 episodes): -48.86
# Timestep: 327000, episode reward (moving average, 20 episodes): -66.47
# Timestep: 328000, episode reward (moving average, 20 episodes): -73.35
# Timestep: 329000, episode reward (moving average, 20 episodes): -75.74
# Timestep: 330000, episode reward (moving average, 20 episodes): -77.23
# Timestep: 331000, episode reward (moving average, 20 episodes): -75.25
# Timestep: 332000, episode reward (moving average, 20 episodes): -55.39
# Timestep: 333000, episode reward (moving average, 20 episodes): -27.25
# Timestep: 334000, episode reward (moving average, 20 episodes): -2.3
# Timestep: 335000, episode reward (moving average, 20 episodes): 20.9
# Timestep: 336000, episode reward (moving average, 20 episodes): 20.82
# Timestep: 337000, episode reward (moving average, 20 episodes): 10.07
# Timestep: 338000, episode reward (moving average, 20 episodes): -46.72
# Timestep: 339000, episode reward (moving average, 20 episodes): -106.29
# Timestep: 340000, episode reward (moving average, 20 episodes): -134.68
# Timestep: 341000, episode reward (moving average, 20 episodes): -150.04
# Timestep: 342000, episode reward (moving average, 20 episodes): -137.22
# Timestep: 343000, episode reward (moving average, 20 episodes): -136.71
# Timestep: 344000, episode reward (moving average, 20 episodes): -116.66
# Timestep: 345000, episode reward (moving average, 20 episodes): -100.36
# Timestep: 346000, episode reward (moving average, 20 episodes): -90.4
# Timestep: 347000, episode reward (moving average, 20 episodes): -85.45
# Timestep: 348000, episode reward (moving average, 20 episodes): -75.52
# Timestep: 349000, episode reward (moving average, 20 episodes): -59.14
# Timestep: 350000, episode reward (moving average, 20 episodes): -53.45
# Timestep: 351000, episode reward (moving average, 20 episodes): -51.33
# Timestep: 352000, episode reward (moving average, 20 episodes): -45.08
# Timestep: 353000, episode reward (moving average, 20 episodes): -39.44
# Timestep: 354000, episode reward (moving average, 20 episodes): -12.69
# Timestep: 355000, episode reward (moving average, 20 episodes): 4.55
# Timestep: 356000, episode reward (moving average, 20 episodes): -8.21
# Timestep: 357000, episode reward (moving average, 20 episodes): -6.76
# Timestep: 358000, episode reward (moving average, 20 episodes): 8.38
# Timestep: 359000, episode reward (moving average, 20 episodes): -5.77
# Timestep: 360000, episode reward (moving average, 20 episodes): 18.55
# Timestep: 361000, episode reward (moving average, 20 episodes): 43.67
# Timestep: 362000, episode reward (moving average, 20 episodes): 63.35
# Timestep: 363000, episode reward (moving average, 20 episodes): 63.13
# Timestep: 364000, episode reward (moving average, 20 episodes): 62.28
# Timestep: 365000, episode reward (moving average, 20 episodes): 62.38
# Timestep: 366000, episode reward (moving average, 20 episodes): 58.74
# Timestep: 367000, episode reward (moving average, 20 episodes): 63.16
# Timestep: 368000, episode reward (moving average, 20 episodes): 62.99
# Timestep: 369000, episode reward (moving average, 20 episodes): 76.86
# Timestep: 370000, episode reward (moving average, 20 episodes): 71.95
# Timestep: 371000, episode reward (moving average, 20 episodes): 71.86
# Timestep: 372000, episode reward (moving average, 20 episodes): 62.54
# Timestep: 373000, episode reward (moving average, 20 episodes): 64.02
# Timestep: 374000, episode reward (moving average, 20 episodes): 73.89
# Timestep: 375000, episode reward (moving average, 20 episodes): 89.15
# Timestep: 376000, episode reward (moving average, 20 episodes): 69.02
# Timestep: 377000, episode reward (moving average, 20 episodes): 65.01
# Timestep: 378000, episode reward (moving average, 20 episodes): 64.06
# Timestep: 379000, episode reward (moving average, 20 episodes): 64.09
# Timestep: 380000, episode reward (moving average, 20 episodes): 52.29
# Timestep: 381000, episode reward (moving average, 20 episodes): 40.43
# Timestep: 382000, episode reward (moving average, 20 episodes): 36.38
# Timestep: 383000, episode reward (moving average, 20 episodes): 22.55
# Timestep: 384000, episode reward (moving average, 20 episodes): -17.94
# Timestep: 385000, episode reward (moving average, 20 episodes): -46.25
# Timestep: 386000, episode reward (moving average, 20 episodes): -67.2
# Timestep: 387000, episode reward (moving average, 20 episodes): -52.37
# Timestep: 388000, episode reward (moving average, 20 episodes): -47.16
# Timestep: 389000, episode reward (moving average, 20 episodes): -45.76
# Timestep: 390000, episode reward (moving average, 20 episodes): -44.52
# Timestep: 391000, episode reward (moving average, 20 episodes): -46.86
# Timestep: 392000, episode reward (moving average, 20 episodes): -22.21
# Timestep: 393000, episode reward (moving average, 20 episodes): -33.84
# Timestep: 394000, episode reward (moving average, 20 episodes): -34.67
# Timestep: 395000, episode reward (moving average, 20 episodes): 1.03
# Timestep: 396000, episode reward (moving average, 20 episodes): 18.62
# Timestep: 397000, episode reward (moving average, 20 episodes): 30.67
# Timestep: 398000, episode reward (moving average, 20 episodes): 53.69
# Timestep: 399000, episode reward (moving average, 20 episodes): 79.32
# Timestep: 400000, episode reward (moving average, 20 episodes): 86.78
# Timestep: 401000, episode reward (moving average, 20 episodes): 84.59
# Timestep: 402000, episode reward (moving average, 20 episodes): 86.7
# Timestep: 403000, episode reward (moving average, 20 episodes): 71.3
# Timestep: 404000, episode reward (moving average, 20 episodes): 76.88
# Timestep: 405000, episode reward (moving average, 20 episodes): 63.71
# Timestep: 406000, episode reward (moving average, 20 episodes): 49.66
# Timestep: 407000, episode reward (moving average, 20 episodes): 59.0
# Timestep: 408000, episode reward (moving average, 20 episodes): 49.38
# Timestep: 409000, episode reward (moving average, 20 episodes): 49.22
# Timestep: 410000, episode reward (moving average, 20 episodes): 51.33
# Timestep: 411000, episode reward (moving average, 20 episodes): 47.18
# Timestep: 412000, episode reward (moving average, 20 episodes): 54.45
# Timestep: 413000, episode reward (moving average, 20 episodes): 10.63
# Timestep: 414000, episode reward (moving average, 20 episodes): 16.79
# Timestep: 415000, episode reward (moving average, 20 episodes): -7.63
# Timestep: 416000, episode reward (moving average, 20 episodes): 10.04
# Timestep: 417000, episode reward (moving average, 20 episodes): 11.23
# Timestep: 418000, episode reward (moving average, 20 episodes): -7.06
# Timestep: 419000, episode reward (moving average, 20 episodes): 4.47
# Timestep: 420000, episode reward (moving average, 20 episodes): 4.61
# Timestep: 421000, episode reward (moving average, 20 episodes): 6.44
# Timestep: 422000, episode reward (moving average, 20 episodes): -23.83
# Timestep: 423000, episode reward (moving average, 20 episodes): -67.72
# Timestep: 424000, episode reward (moving average, 20 episodes): -72.12
# Timestep: 425000, episode reward (moving average, 20 episodes): -144.73
# Timestep: 426000, episode reward (moving average, 20 episodes): -141.8
# Timestep: 427000, episode reward (moving average, 20 episodes): -169.24
# Timestep: 428000, episode reward (moving average, 20 episodes): -192.74
# Timestep: 429000, episode reward (moving average, 20 episodes): -196.6
# Timestep: 430000, episode reward (moving average, 20 episodes): -189.45
# Timestep: 431000, episode reward (moving average, 20 episodes): -177.26
# Timestep: 432000, episode reward (moving average, 20 episodes): -210.3
# Timestep: 433000, episode reward (moving average, 20 episodes): -211.99
# Timestep: 434000, episode reward (moving average, 20 episodes): -199.18
# Timestep: 435000, episode reward (moving average, 20 episodes): -235.98
# Timestep: 436000, episode reward (moving average, 20 episodes): -244.68
# Timestep: 437000, episode reward (moving average, 20 episodes): -249.23
# Timestep: 438000, episode reward (moving average, 20 episodes): -231.87
# Timestep: 439000, episode reward (moving average, 20 episodes): -226.32
# Timestep: 440000, episode reward (moving average, 20 episodes): -229.32
# Timestep: 441000, episode reward (moving average, 20 episodes): -272.51
# Timestep: 442000, episode reward (moving average, 20 episodes): -263.79
# Timestep: 443000, episode reward (moving average, 20 episodes): -261.74
# Timestep: 444000, episode reward (moving average, 20 episodes): -211.14
# Timestep: 445000, episode reward (moving average, 20 episodes): -194.86
# Timestep: 446000, episode reward (moving average, 20 episodes): -190.55
# Timestep: 447000, episode reward (moving average, 20 episodes): -173.52
# Timestep: 448000, episode reward (moving average, 20 episodes): -145.96
# Timestep: 449000, episode reward (moving average, 20 episodes): -154.61
# Timestep: 450000, episode reward (moving average, 20 episodes): -171.25
# Timestep: 451000, episode reward (moving average, 20 episodes): -134.14
# Timestep: 452000, episode reward (moving average, 20 episodes): -84.55
# Timestep: 453000, episode reward (moving average, 20 episodes): -108.13
# Timestep: 454000, episode reward (moving average, 20 episodes): -63.47
# Timestep: 455000, episode reward (moving average, 20 episodes): -87.41
# Timestep: 456000, episode reward (moving average, 20 episodes): -8.09
# Timestep: 457000, episode reward (moving average, 20 episodes): 2.69
# Timestep: 458000, episode reward (moving average, 20 episodes): -2.26
# Timestep: 459000, episode reward (moving average, 20 episodes): -39.88
# Timestep: 460000, episode reward (moving average, 20 episodes): -25.81
# Timestep: 461000, episode reward (moving average, 20 episodes): -63.08
# Timestep: 462000, episode reward (moving average, 20 episodes): -74.12
# Timestep: 463000, episode reward (moving average, 20 episodes): -75.66
# Timestep: 464000, episode reward (moving average, 20 episodes): -85.04
# Timestep: 465000, episode reward (moving average, 20 episodes): -80.3
# Timestep: 466000, episode reward (moving average, 20 episodes): -77.27
# Timestep: 467000, episode reward (moving average, 20 episodes): -36.25
# Timestep: 468000, episode reward (moving average, 20 episodes): -3.42
# Timestep: 469000, episode reward (moving average, 20 episodes): -1.56
# Timestep: 470000, episode reward (moving average, 20 episodes): 34.19
# Timestep: 471000, episode reward (moving average, 20 episodes): 69.92
# Timestep: 472000, episode reward (moving average, 20 episodes): 56.85
# Timestep: 473000, episode reward (moving average, 20 episodes): 106.96
# Timestep: 474000, episode reward (moving average, 20 episodes): 134.87
# Timestep: 475000, episode reward (moving average, 20 episodes): 80.05
# Timestep: 476000, episode reward (moving average, 20 episodes): 107.53
# Timestep: 477000, episode reward (moving average, 20 episodes): 108.84
# Timestep: 478000, episode reward (moving average, 20 episodes): 113.56
# Timestep: 479000, episode reward (moving average, 20 episodes): 145.09
# Timestep: 480000, episode reward (moving average, 20 episodes): 120.36
# Timestep: 481000, episode reward (moving average, 20 episodes): 155.01
# Timestep: 482000, episode reward (moving average, 20 episodes): 139.9
# Timestep: 483000, episode reward (moving average, 20 episodes): 112.23
# Timestep: 484000, episode reward (moving average, 20 episodes): 126.24
# Timestep: 485000, episode reward (moving average, 20 episodes): 149.19
# Timestep: 486000, episode reward (moving average, 20 episodes): 165.08
# Timestep: 487000, episode reward (moving average, 20 episodes): 182.5
# Timestep: 488000, episode reward (moving average, 20 episodes): 217.17
# Timestep: 489000, episode reward (moving average, 20 episodes): 225.23
# Timestep: 490000, episode reward (moving average, 20 episodes): 244.11
# Timestep: 491000, episode reward (moving average, 20 episodes): 239.74
# Timestep: 492000, episode reward (moving average, 20 episodes): 217.37
# Timestep: 493000, episode reward (moving average, 20 episodes): 213.15
# Timestep: 494000, episode reward (moving average, 20 episodes): 178.6
# Timestep: 495000, episode reward (moving average, 20 episodes): 173.2
# Timestep: 496000, episode reward (moving average, 20 episodes): 158.38
# Timestep: 497000, episode reward (moving average, 20 episodes): 130.14
# Timestep: 498000, episode reward (moving average, 20 episodes): 123.76
# Timestep: 499000, episode reward (moving average, 20 episodes): 123.83
# Timestep: 500000, episode reward (moving average, 20 episodes): 122.07

# %% [markdown]
# #### Comments
#
# `During the training process, the return values exhibit a spiral-shaped ascent.`
# `Additionally, due to a low lower bound and a high upper bound, the standard deviation is extremely large.`
# `That could be a result of the model exploring a diverse range of values during training, indicating variability and uncertainty in the learning process.`

# %% [markdown]
# ## Point 1.2
#
# The performance of RL algorithms typically varies across runs. Report results of five runs of your algorithm and summarize the performance in a single plot.

# %%
agents_5runs = []
for _ in range(5):
    agent = DDPG(env, total_timesteps=int(3e5))
    agent.train(make_plot=False)
    agents_5runs.append(agent)
# Out:
# Timestep: 1000, episode reward (moving average, 20 episodes): -152.45
# Timestep: 2000, episode reward (moving average, 20 episodes): -254.93
# Timestep: 3000, episode reward (moving average, 20 episodes): -273.12
# Timestep: 4000, episode reward (moving average, 20 episodes): -234.54
# Timestep: 5000, episode reward (moving average, 20 episodes): -192.29
# Timestep: 6000, episode reward (moving average, 20 episodes): -175.22
# Timestep: 7000, episode reward (moving average, 20 episodes): -158.57
# Timestep: 8000, episode reward (moving average, 20 episodes): -160.26
# Timestep: 9000, episode reward (moving average, 20 episodes): -177.87
# Timestep: 10000, episode reward (moving average, 20 episodes): -181.93
# Timestep: 11000, episode reward (moving average, 20 episodes): -187.61
# Timestep: 12000, episode reward (moving average, 20 episodes): -191.8
# Timestep: 13000, episode reward (moving average, 20 episodes): -196.18
# Timestep: 14000, episode reward (moving average, 20 episodes): -210.35
# Timestep: 15000, episode reward (moving average, 20 episodes): -179.06
# Timestep: 16000, episode reward (moving average, 20 episodes): -166.45
# Timestep: 17000, episode reward (moving average, 20 episodes): -139.14
# Timestep: 18000, episode reward (moving average, 20 episodes): -150.4
# Timestep: 19000, episode reward (moving average, 20 episodes): -138.86
# Timestep: 20000, episode reward (moving average, 20 episodes): -113.0
# Timestep: 21000, episode reward (moving average, 20 episodes): -105.69
# Timestep: 22000, episode reward (moving average, 20 episodes): -88.88
# Timestep: 23000, episode reward (moving average, 20 episodes): -79.38
# Timestep: 24000, episode reward (moving average, 20 episodes): -104.43
# Timestep: 25000, episode reward (moving average, 20 episodes): -97.25
# Timestep: 26000, episode reward (moving average, 20 episodes): -91.73
# Timestep: 27000, episode reward (moving average, 20 episodes): -95.19
# Timestep: 28000, episode reward (moving average, 20 episodes): -94.02
# Timestep: 29000, episode reward (moving average, 20 episodes): -98.18
# Timestep: 30000, episode reward (moving average, 20 episodes): -93.92
# Timestep: 31000, episode reward (moving average, 20 episodes): -92.64
# Timestep: 32000, episode reward (moving average, 20 episodes): -101.25
# Timestep: 33000, episode reward (moving average, 20 episodes): -109.56
# Timestep: 34000, episode reward (moving average, 20 episodes): -132.05
# Timestep: 35000, episode reward (moving average, 20 episodes): -148.56
# Timestep: 36000, episode reward (moving average, 20 episodes): -153.62
# Timestep: 37000, episode reward (moving average, 20 episodes): -159.31
# Timestep: 38000, episode reward (moving average, 20 episodes): -164.61
# Timestep: 39000, episode reward (moving average, 20 episodes): -174.24
# Timestep: 40000, episode reward (moving average, 20 episodes): -185.49
# Timestep: 41000, episode reward (moving average, 20 episodes): -189.36
# Timestep: 42000, episode reward (moving average, 20 episodes): -175.77
# Timestep: 43000, episode reward (moving average, 20 episodes): -181.65
# Timestep: 44000, episode reward (moving average, 20 episodes): -180.17
# Timestep: 45000, episode reward (moving average, 20 episodes): -183.96
# Timestep: 46000, episode reward (moving average, 20 episodes): -183.61
# Timestep: 47000, episode reward (moving average, 20 episodes): -177.31
# Timestep: 48000, episode reward (moving average, 20 episodes): -170.59
# Timestep: 49000, episode reward (moving average, 20 episodes): -166.51
# Timestep: 50000, episode reward (moving average, 20 episodes): -157.45
# Timestep: 51000, episode reward (moving average, 20 episodes): -149.23
# Timestep: 52000, episode reward (moving average, 20 episodes): -157.13
# Timestep: 53000, episode reward (moving average, 20 episodes): -155.91
# Timestep: 54000, episode reward (moving average, 20 episodes): -183.98
# Timestep: 55000, episode reward (moving average, 20 episodes): -193.52
# Timestep: 56000, episode reward (moving average, 20 episodes): -184.88
# Timestep: 57000, episode reward (moving average, 20 episodes): -186.44
# Timestep: 58000, episode reward (moving average, 20 episodes): -203.33
# Timestep: 59000, episode reward (moving average, 20 episodes): -201.89
# Timestep: 60000, episode reward (moving average, 20 episodes): -197.74
# Timestep: 61000, episode reward (moving average, 20 episodes): -203.73
# Timestep: 62000, episode reward (moving average, 20 episodes): -184.86
# Timestep: 63000, episode reward (moving average, 20 episodes): -180.9
# Timestep: 64000, episode reward (moving average, 20 episodes): -183.79
# Timestep: 65000, episode reward (moving average, 20 episodes): -156.06
# Timestep: 66000, episode reward (moving average, 20 episodes): -170.57
# Timestep: 67000, episode reward (moving average, 20 episodes): -175.29
# Timestep: 68000, episode reward (moving average, 20 episodes): -160.51
# Timestep: 69000, episode reward (moving average, 20 episodes): -165.84
# Timestep: 70000, episode reward (moving average, 20 episodes): -161.19
# Timestep: 71000, episode reward (moving average, 20 episodes): -159.29
# Timestep: 72000, episode reward (moving average, 20 episodes): -157.89
# Timestep: 73000, episode reward (moving average, 20 episodes): -181.21
# Timestep: 74000, episode reward (moving average, 20 episodes): -191.41
# Timestep: 75000, episode reward (moving average, 20 episodes): -197.31
# Timestep: 76000, episode reward (moving average, 20 episodes): -200.15
# Timestep: 77000, episode reward (moving average, 20 episodes): -184.23
# Timestep: 78000, episode reward (moving average, 20 episodes): -181.78
# Timestep: 79000, episode reward (moving average, 20 episodes): -181.96
# Timestep: 80000, episode reward (moving average, 20 episodes): -181.0
# Timestep: 81000, episode reward (moving average, 20 episodes): -177.17
# Timestep: 82000, episode reward (moving average, 20 episodes): -165.2
# Timestep: 83000, episode reward (moving average, 20 episodes): -164.96
# Timestep: 84000, episode reward (moving average, 20 episodes): -163.92
# Timestep: 85000, episode reward (moving average, 20 episodes): -163.04
# Timestep: 86000, episode reward (moving average, 20 episodes): -165.32
# Timestep: 87000, episode reward (moving average, 20 episodes): -162.46
# Timestep: 88000, episode reward (moving average, 20 episodes): -163.8
# Timestep: 89000, episode reward (moving average, 20 episodes): -159.78
# Timestep: 90000, episode reward (moving average, 20 episodes): -154.54
# Timestep: 91000, episode reward (moving average, 20 episodes): -131.08
# Timestep: 92000, episode reward (moving average, 20 episodes): -130.7
# Timestep: 93000, episode reward (moving average, 20 episodes): -124.31
# Timestep: 94000, episode reward (moving average, 20 episodes): -128.33
# Timestep: 95000, episode reward (moving average, 20 episodes): -128.72
# Timestep: 96000, episode reward (moving average, 20 episodes): -132.22
# Timestep: 97000, episode reward (moving average, 20 episodes): -148.28
# Timestep: 98000, episode reward (moving average, 20 episodes): -159.69
# Timestep: 99000, episode reward (moving average, 20 episodes): -165.75
# Timestep: 100000, episode reward (moving average, 20 episodes): -171.39
# Timestep: 101000, episode reward (moving average, 20 episodes): -174.23
# Timestep: 102000, episode reward (moving average, 20 episodes): -175.72
# Timestep: 103000, episode reward (moving average, 20 episodes): -176.85
# Timestep: 104000, episode reward (moving average, 20 episodes): -176.14
# Timestep: 105000, episode reward (moving average, 20 episodes): -181.83
# Timestep: 106000, episode reward (moving average, 20 episodes): -175.73
# Timestep: 107000, episode reward (moving average, 20 episodes): -182.88
# Timestep: 108000, episode reward (moving average, 20 episodes): -179.18
# Timestep: 109000, episode reward (moving average, 20 episodes): -172.03
# Timestep: 110000, episode reward (moving average, 20 episodes): -168.73
# Timestep: 111000, episode reward (moving average, 20 episodes): -160.9
# Timestep: 112000, episode reward (moving average, 20 episodes): -155.03
# Timestep: 113000, episode reward (moving average, 20 episodes): -150.03
# Timestep: 114000, episode reward (moving average, 20 episodes): -147.15
# Timestep: 115000, episode reward (moving average, 20 episodes): -141.34
# Timestep: 116000, episode reward (moving average, 20 episodes): -133.92
# Timestep: 117000, episode reward (moving average, 20 episodes): -135.04
# Timestep: 118000, episode reward (moving average, 20 episodes): -125.77
# Timestep: 119000, episode reward (moving average, 20 episodes): -122.21
# Timestep: 120000, episode reward (moving average, 20 episodes): -120.35
# Timestep: 121000, episode reward (moving average, 20 episodes): -118.32
# Timestep: 122000, episode reward (moving average, 20 episodes): -116.51
# Timestep: 123000, episode reward (moving average, 20 episodes): -105.78
# Timestep: 124000, episode reward (moving average, 20 episodes): -103.93
# Timestep: 125000, episode reward (moving average, 20 episodes): -115.86
# Timestep: 126000, episode reward (moving average, 20 episodes): -124.23
# Timestep: 127000, episode reward (moving average, 20 episodes): -121.86
# Timestep: 128000, episode reward (moving average, 20 episodes): -123.31
# Timestep: 129000, episode reward (moving average, 20 episodes): -123.77
# Timestep: 130000, episode reward (moving average, 20 episodes): -121.55
# Timestep: 131000, episode reward (moving average, 20 episodes): -113.46
# Timestep: 132000, episode reward (moving average, 20 episodes): -106.51
# Timestep: 133000, episode reward (moving average, 20 episodes): -99.12
# Timestep: 134000, episode reward (moving average, 20 episodes): -94.49
# Timestep: 135000, episode reward (moving average, 20 episodes): -93.59
# Timestep: 136000, episode reward (moving average, 20 episodes): -89.82
# Timestep: 137000, episode reward (moving average, 20 episodes): -67.91
# Timestep: 138000, episode reward (moving average, 20 episodes): -73.96
# Timestep: 139000, episode reward (moving average, 20 episodes): -67.43
# Timestep: 140000, episode reward (moving average, 20 episodes): -70.3
# Timestep: 141000, episode reward (moving average, 20 episodes): -95.91
# Timestep: 142000, episode reward (moving average, 20 episodes): -94.99
# Timestep: 143000, episode reward (moving average, 20 episodes): -94.47
# Timestep: 144000, episode reward (moving average, 20 episodes): -93.24
# Timestep: 145000, episode reward (moving average, 20 episodes): -93.58
# Timestep: 146000, episode reward (moving average, 20 episodes): -100.45
# Timestep: 147000, episode reward (moving average, 20 episodes): -109.36
# Timestep: 148000, episode reward (moving average, 20 episodes): -110.13
# Timestep: 149000, episode reward (moving average, 20 episodes): -115.96
# Timestep: 150000, episode reward (moving average, 20 episodes): -124.28
# Timestep: 151000, episode reward (moving average, 20 episodes): -120.54
# Timestep: 152000, episode reward (moving average, 20 episodes): -116.93
# Timestep: 153000, episode reward (moving average, 20 episodes): -111.27
# Timestep: 154000, episode reward (moving average, 20 episodes): -108.1
# Timestep: 155000, episode reward (moving average, 20 episodes): -109.94
# Timestep: 156000, episode reward (moving average, 20 episodes): -110.92
# Timestep: 157000, episode reward (moving average, 20 episodes): -109.99
# Timestep: 158000, episode reward (moving average, 20 episodes): -103.27
# Timestep: 159000, episode reward (moving average, 20 episodes): -101.97
# Timestep: 160000, episode reward (moving average, 20 episodes): -88.54
# Timestep: 161000, episode reward (moving average, 20 episodes): -86.37
# Timestep: 162000, episode reward (moving average, 20 episodes): -78.96
# Timestep: 163000, episode reward (moving average, 20 episodes): -91.38
# Timestep: 164000, episode reward (moving average, 20 episodes): -93.31
# Timestep: 165000, episode reward (moving average, 20 episodes): -91.91
# Timestep: 166000, episode reward (moving average, 20 episodes): -81.22
# Timestep: 167000, episode reward (moving average, 20 episodes): -78.04
# Timestep: 168000, episode reward (moving average, 20 episodes): -72.91
# Timestep: 169000, episode reward (moving average, 20 episodes): -69.9
# Timestep: 170000, episode reward (moving average, 20 episodes): -76.27
# Timestep: 171000, episode reward (moving average, 20 episodes): -75.87
# Timestep: 172000, episode reward (moving average, 20 episodes): -76.75
# Timestep: 173000, episode reward (moving average, 20 episodes): -74.66
# Timestep: 174000, episode reward (moving average, 20 episodes): -71.46
# Timestep: 175000, episode reward (moving average, 20 episodes): -70.16
# Timestep: 176000, episode reward (moving average, 20 episodes): -66.35
# Timestep: 177000, episode reward (moving average, 20 episodes): -61.69
# Timestep: 178000, episode reward (moving average, 20 episodes): -76.06
# Timestep: 179000, episode reward (moving average, 20 episodes): -70.9
# Timestep: 180000, episode reward (moving average, 20 episodes): -71.59
# Timestep: 181000, episode reward (moving average, 20 episodes): -74.23
# Timestep: 182000, episode reward (moving average, 20 episodes): -75.07
# Timestep: 183000, episode reward (moving average, 20 episodes): -70.24
# Timestep: 184000, episode reward (moving average, 20 episodes): -70.11
# Timestep: 185000, episode reward (moving average, 20 episodes): -69.4
# Timestep: 186000, episode reward (moving average, 20 episodes): -68.9
# Timestep: 187000, episode reward (moving average, 20 episodes): -58.66
# Timestep: 188000, episode reward (moving average, 20 episodes): -60.78
# Timestep: 189000, episode reward (moving average, 20 episodes): -59.93
# Timestep: 190000, episode reward (moving average, 20 episodes): -59.05
# Timestep: 191000, episode reward (moving average, 20 episodes): -65.71
# Timestep: 192000, episode reward (moving average, 20 episodes): -66.12
# Timestep: 193000, episode reward (moving average, 20 episodes): -76.21
# Timestep: 194000, episode reward (moving average, 20 episodes): -61.74
# Timestep: 195000, episode reward (moving average, 20 episodes): -58.16
# Timestep: 196000, episode reward (moving average, 20 episodes): -107.8
# Timestep: 197000, episode reward (moving average, 20 episodes): -96.62
# Timestep: 198000, episode reward (moving average, 20 episodes): -95.81
# Timestep: 199000, episode reward (moving average, 20 episodes): -96.11
# Timestep: 200000, episode reward (moving average, 20 episodes): -107.05
# Timestep: 201000, episode reward (moving average, 20 episodes): -123.7
# Timestep: 202000, episode reward (moving average, 20 episodes): -134.28
# Timestep: 203000, episode reward (moving average, 20 episodes): -130.59
# Timestep: 204000, episode reward (moving average, 20 episodes): -136.02
# Timestep: 205000, episode reward (moving average, 20 episodes): -140.15
# Timestep: 206000, episode reward (moving average, 20 episodes): -107.89
# Timestep: 207000, episode reward (moving average, 20 episodes): -89.4
# Timestep: 208000, episode reward (moving average, 20 episodes): -84.26
# Timestep: 209000, episode reward (moving average, 20 episodes): -92.84
# Timestep: 210000, episode reward (moving average, 20 episodes): -99.24
# Timestep: 211000, episode reward (moving average, 20 episodes): -106.05
# Timestep: 212000, episode reward (moving average, 20 episodes): -111.22
# Timestep: 213000, episode reward (moving average, 20 episodes): -126.42
# Timestep: 214000, episode reward (moving average, 20 episodes): -116.83
# Timestep: 215000, episode reward (moving average, 20 episodes): -121.23
# Timestep: 216000, episode reward (moving average, 20 episodes): -98.22
# Timestep: 217000, episode reward (moving average, 20 episodes): -98.61
# Timestep: 218000, episode reward (moving average, 20 episodes): -89.72
# Timestep: 219000, episode reward (moving average, 20 episodes): -91.31
# Timestep: 220000, episode reward (moving average, 20 episodes): -84.69
# Timestep: 221000, episode reward (moving average, 20 episodes): -103.84
# Timestep: 222000, episode reward (moving average, 20 episodes): -92.17
# Timestep: 223000, episode reward (moving average, 20 episodes): -98.05
# Timestep: 224000, episode reward (moving average, 20 episodes): -98.99
# Timestep: 225000, episode reward (moving average, 20 episodes): -98.38
# Timestep: 226000, episode reward (moving average, 20 episodes): -92.76
# Timestep: 227000, episode reward (moving average, 20 episodes): -88.79
# Timestep: 228000, episode reward (moving average, 20 episodes): -83.73
# Timestep: 229000, episode reward (moving average, 20 episodes): -92.57
# Timestep: 230000, episode reward (moving average, 20 episodes): -85.12
# Timestep: 231000, episode reward (moving average, 20 episodes): -84.3
# Timestep: 232000, episode reward (moving average, 20 episodes): -81.23
# Timestep: 233000, episode reward (moving average, 20 episodes): -77.7
# Timestep: 234000, episode reward (moving average, 20 episodes): -78.21
# Timestep: 235000, episode reward (moving average, 20 episodes): -75.2
# Timestep: 236000, episode reward (moving average, 20 episodes): -74.21
# Timestep: 237000, episode reward (moving average, 20 episodes): -73.2
# Timestep: 238000, episode reward (moving average, 20 episodes): -75.38
# Timestep: 239000, episode reward (moving average, 20 episodes): -61.65
# Timestep: 240000, episode reward (moving average, 20 episodes): -63.42
# Timestep: 241000, episode reward (moving average, 20 episodes): -64.27
# Timestep: 242000, episode reward (moving average, 20 episodes): -58.28
# Timestep: 243000, episode reward (moving average, 20 episodes): -58.19
# Timestep: 244000, episode reward (moving average, 20 episodes): -58.26
# Timestep: 245000, episode reward (moving average, 20 episodes): -45.92
# Timestep: 246000, episode reward (moving average, 20 episodes): -43.55
# Timestep: 247000, episode reward (moving average, 20 episodes): -26.08
# Timestep: 248000, episode reward (moving average, 20 episodes): -24.44
# Timestep: 249000, episode reward (moving average, 20 episodes): -25.62
# Timestep: 250000, episode reward (moving average, 20 episodes): -33.41
# Timestep: 251000, episode reward (moving average, 20 episodes): -20.18
# Timestep: 252000, episode reward (moving average, 20 episodes): -13.16
# Timestep: 253000, episode reward (moving average, 20 episodes): -9.95
# Timestep: 254000, episode reward (moving average, 20 episodes): -27.07
# Timestep: 255000, episode reward (moving average, 20 episodes): -26.96
# Timestep: 256000, episode reward (moving average, 20 episodes): -29.13
# Timestep: 257000, episode reward (moving average, 20 episodes): -35.73
# Timestep: 258000, episode reward (moving average, 20 episodes): -27.42
# Timestep: 259000, episode reward (moving average, 20 episodes): -36.68
# Timestep: 260000, episode reward (moving average, 20 episodes): -34.01
# Timestep: 261000, episode reward (moving average, 20 episodes): -33.08
# Timestep: 262000, episode reward (moving average, 20 episodes): -33.31
# Timestep: 263000, episode reward (moving average, 20 episodes): -34.73
# Timestep: 264000, episode reward (moving average, 20 episodes): -36.49
# Timestep: 265000, episode reward (moving average, 20 episodes): -39.77
# Timestep: 266000, episode reward (moving average, 20 episodes): -41.07
# Timestep: 267000, episode reward (moving average, 20 episodes): -20.22
# Timestep: 268000, episode reward (moving average, 20 episodes): -22.11
# Timestep: 269000, episode reward (moving average, 20 episodes): -27.26
# Timestep: 270000, episode reward (moving average, 20 episodes): -38.77
# Timestep: 271000, episode reward (moving average, 20 episodes): -41.54
# Timestep: 272000, episode reward (moving average, 20 episodes): -43.4
# Timestep: 273000, episode reward (moving average, 20 episodes): -49.13
# Timestep: 274000, episode reward (moving average, 20 episodes): -47.61
# Timestep: 275000, episode reward (moving average, 20 episodes): -50.01
# Timestep: 276000, episode reward (moving average, 20 episodes): -51.19
# Timestep: 277000, episode reward (moving average, 20 episodes): -67.35
# Timestep: 278000, episode reward (moving average, 20 episodes): -96.62
# Timestep: 279000, episode reward (moving average, 20 episodes): -88.82
# Timestep: 280000, episode reward (moving average, 20 episodes): -93.28
# Timestep: 281000, episode reward (moving average, 20 episodes): -100.17
# Timestep: 282000, episode reward (moving average, 20 episodes): -100.76
# Timestep: 283000, episode reward (moving average, 20 episodes): -105.81
# Timestep: 284000, episode reward (moving average, 20 episodes): -92.15
# Timestep: 285000, episode reward (moving average, 20 episodes): -92.03
# Timestep: 286000, episode reward (moving average, 20 episodes): -93.06
# Timestep: 287000, episode reward (moving average, 20 episodes): -68.16
# Timestep: 288000, episode reward (moving average, 20 episodes): -60.4
# Timestep: 289000, episode reward (moving average, 20 episodes): -47.02
# Timestep: 290000, episode reward (moving average, 20 episodes): -44.91
# Timestep: 291000, episode reward (moving average, 20 episodes): -28.37
# Timestep: 292000, episode reward (moving average, 20 episodes): -26.75
# Timestep: 293000, episode reward (moving average, 20 episodes): -5.93
# Timestep: 294000, episode reward (moving average, 20 episodes): 15.62
# Timestep: 295000, episode reward (moving average, 20 episodes): 17.26
# Timestep: 296000, episode reward (moving average, 20 episodes): 47.29
# Timestep: 297000, episode reward (moving average, 20 episodes): 46.33
# Timestep: 298000, episode reward (moving average, 20 episodes): 50.03
# Timestep: 299000, episode reward (moving average, 20 episodes): 50.03
# Timestep: 300000, episode reward (moving average, 20 episodes): 122.07
# Timestep: 1000, episode reward (moving average, 20 episodes): -189.18
# Timestep: 2000, episode reward (moving average, 20 episodes): -228.06
# Timestep: 3000, episode reward (moving average, 20 episodes): -218.38
# Timestep: 4000, episode reward (moving average, 20 episodes): -229.01
# Timestep: 5000, episode reward (moving average, 20 episodes): -208.05
# Timestep: 6000, episode reward (moving average, 20 episodes): -203.61
# Timestep: 7000, episode reward (moving average, 20 episodes): -214.64
# Timestep: 8000, episode reward (moving average, 20 episodes): -227.09
# Timestep: 9000, episode reward (moving average, 20 episodes): -227.66
# Timestep: 10000, episode reward (moving average, 20 episodes): -202.21
# Timestep: 11000, episode reward (moving average, 20 episodes): -197.7
# Timestep: 12000, episode reward (moving average, 20 episodes): -195.95
# Timestep: 13000, episode reward (moving average, 20 episodes): -207.8
# Timestep: 14000, episode reward (moving average, 20 episodes): -214.85
# Timestep: 15000, episode reward (moving average, 20 episodes): -192.02
# Timestep: 16000, episode reward (moving average, 20 episodes): -186.74
# Timestep: 17000, episode reward (moving average, 20 episodes): -191.49
# Timestep: 18000, episode reward (moving average, 20 episodes): -187.25
# Timestep: 19000, episode reward (moving average, 20 episodes): -185.85
# Timestep: 20000, episode reward (moving average, 20 episodes): -163.63
# Timestep: 21000, episode reward (moving average, 20 episodes): -177.82
# Timestep: 22000, episode reward (moving average, 20 episodes): -158.47
# Timestep: 23000, episode reward (moving average, 20 episodes): -163.94
# Timestep: 24000, episode reward (moving average, 20 episodes): -173.58
# Timestep: 25000, episode reward (moving average, 20 episodes): -164.48
# Timestep: 26000, episode reward (moving average, 20 episodes): -150.99
# Timestep: 27000, episode reward (moving average, 20 episodes): -165.68
# Timestep: 28000, episode reward (moving average, 20 episodes): -161.81
# Timestep: 29000, episode reward (moving average, 20 episodes): -132.99
# Timestep: 30000, episode reward (moving average, 20 episodes): -117.53
# Timestep: 31000, episode reward (moving average, 20 episodes): -114.34
# Timestep: 32000, episode reward (moving average, 20 episodes): -116.81
# Timestep: 33000, episode reward (moving average, 20 episodes): -138.33
# Timestep: 34000, episode reward (moving average, 20 episodes): -136.8
# Timestep: 35000, episode reward (moving average, 20 episodes): -130.29
# Timestep: 36000, episode reward (moving average, 20 episodes): -140.71
# Timestep: 37000, episode reward (moving average, 20 episodes): -125.77
# Timestep: 38000, episode reward (moving average, 20 episodes): -137.75
# Timestep: 39000, episode reward (moving average, 20 episodes): -172.84
# Timestep: 40000, episode reward (moving average, 20 episodes): -180.64
# Timestep: 41000, episode reward (moving average, 20 episodes): -209.54
# Timestep: 42000, episode reward (moving average, 20 episodes): -240.93
# Timestep: 43000, episode reward (moving average, 20 episodes): -231.58
# Timestep: 44000, episode reward (moving average, 20 episodes): -225.08
# Timestep: 45000, episode reward (moving average, 20 episodes): -224.06
# Timestep: 46000, episode reward (moving average, 20 episodes): -222.32
# Timestep: 47000, episode reward (moving average, 20 episodes): -183.9
# Timestep: 48000, episode reward (moving average, 20 episodes): -167.47
# Timestep: 49000, episode reward (moving average, 20 episodes): -174.12
# Timestep: 50000, episode reward (moving average, 20 episodes): -166.27
# Timestep: 51000, episode reward (moving average, 20 episodes): -177.41
# Timestep: 52000, episode reward (moving average, 20 episodes): -189.93
# Timestep: 53000, episode reward (moving average, 20 episodes): -180.82
# Timestep: 54000, episode reward (moving average, 20 episodes): -176.57
# Timestep: 55000, episode reward (moving average, 20 episodes): -156.85
# Timestep: 56000, episode reward (moving average, 20 episodes): -163.7
# Timestep: 57000, episode reward (moving average, 20 episodes): -144.59
# Timestep: 58000, episode reward (moving average, 20 episodes): -136.77
# Timestep: 59000, episode reward (moving average, 20 episodes): -126.64
# Timestep: 60000, episode reward (moving average, 20 episodes): -143.24
# Timestep: 61000, episode reward (moving average, 20 episodes): -166.37
# Timestep: 62000, episode reward (moving average, 20 episodes): -153.66
# Timestep: 63000, episode reward (moving average, 20 episodes): -156.4
# Timestep: 64000, episode reward (moving average, 20 episodes): -154.38
# Timestep: 65000, episode reward (moving average, 20 episodes): -156.49
# Timestep: 66000, episode reward (moving average, 20 episodes): -162.08
# Timestep: 67000, episode reward (moving average, 20 episodes): -167.12
# Timestep: 68000, episode reward (moving average, 20 episodes): -178.27
# Timestep: 69000, episode reward (moving average, 20 episodes): -179.18
# Timestep: 70000, episode reward (moving average, 20 episodes): -204.72
# Timestep: 71000, episode reward (moving average, 20 episodes): -215.42
# Timestep: 72000, episode reward (moving average, 20 episodes): -210.74
# Timestep: 73000, episode reward (moving average, 20 episodes): -190.53
# Timestep: 74000, episode reward (moving average, 20 episodes): -156.25
# Timestep: 75000, episode reward (moving average, 20 episodes): -142.45
# Timestep: 76000, episode reward (moving average, 20 episodes): -139.34
# Timestep: 77000, episode reward (moving average, 20 episodes): -147.48
# Timestep: 78000, episode reward (moving average, 20 episodes): -167.66
# Timestep: 79000, episode reward (moving average, 20 episodes): -154.35
# Timestep: 80000, episode reward (moving average, 20 episodes): -149.93
# Timestep: 81000, episode reward (moving average, 20 episodes): -161.38
# Timestep: 82000, episode reward (moving average, 20 episodes): -171.34
# Timestep: 83000, episode reward (moving average, 20 episodes): -171.76
# Timestep: 84000, episode reward (moving average, 20 episodes): -169.88
# Timestep: 85000, episode reward (moving average, 20 episodes): -176.11
# Timestep: 86000, episode reward (moving average, 20 episodes): -171.72
# Timestep: 87000, episode reward (moving average, 20 episodes): -168.85
# Timestep: 88000, episode reward (moving average, 20 episodes): -155.35
# Timestep: 89000, episode reward (moving average, 20 episodes): -151.56
# Timestep: 90000, episode reward (moving average, 20 episodes): -160.84
# Timestep: 91000, episode reward (moving average, 20 episodes): -168.3
# Timestep: 92000, episode reward (moving average, 20 episodes): -181.17
# Timestep: 93000, episode reward (moving average, 20 episodes): -179.88
# Timestep: 94000, episode reward (moving average, 20 episodes): -177.62
# Timestep: 95000, episode reward (moving average, 20 episodes): -180.36
# Timestep: 96000, episode reward (moving average, 20 episodes): -188.94
# Timestep: 97000, episode reward (moving average, 20 episodes): -203.17
# Timestep: 98000, episode reward (moving average, 20 episodes): -224.94
# Timestep: 99000, episode reward (moving average, 20 episodes): -224.37
# Timestep: 100000, episode reward (moving average, 20 episodes): -220.95
# Timestep: 101000, episode reward (moving average, 20 episodes): -238.35
# Timestep: 102000, episode reward (moving average, 20 episodes): -236.53
# Timestep: 103000, episode reward (moving average, 20 episodes): -233.06
# Timestep: 104000, episode reward (moving average, 20 episodes): -239.24
# Timestep: 105000, episode reward (moving average, 20 episodes): -240.89
# Timestep: 106000, episode reward (moving average, 20 episodes): -228.4
# Timestep: 107000, episode reward (moving average, 20 episodes): -228.4
# Timestep: 108000, episode reward (moving average, 20 episodes): -218.62
# Timestep: 109000, episode reward (moving average, 20 episodes): -186.16
# Timestep: 110000, episode reward (moving average, 20 episodes): -169.7
# Timestep: 111000, episode reward (moving average, 20 episodes): -168.63
# Timestep: 112000, episode reward (moving average, 20 episodes): -172.44
# Timestep: 113000, episode reward (moving average, 20 episodes): -164.15
# Timestep: 114000, episode reward (moving average, 20 episodes): -172.84
# Timestep: 115000, episode reward (moving average, 20 episodes): -185.68
# Timestep: 116000, episode reward (moving average, 20 episodes): -196.22
# Timestep: 117000, episode reward (moving average, 20 episodes): -220.49
# Timestep: 118000, episode reward (moving average, 20 episodes): -217.65
# Timestep: 119000, episode reward (moving average, 20 episodes): -247.32
# Timestep: 120000, episode reward (moving average, 20 episodes): -256.45
# Timestep: 121000, episode reward (moving average, 20 episodes): -278.34
# Timestep: 122000, episode reward (moving average, 20 episodes): -276.41
# Timestep: 123000, episode reward (moving average, 20 episodes): -275.42
# Timestep: 124000, episode reward (moving average, 20 episodes): -250.67
# Timestep: 125000, episode reward (moving average, 20 episodes): -248.84
# Timestep: 126000, episode reward (moving average, 20 episodes): -237.87
# Timestep: 127000, episode reward (moving average, 20 episodes): -233.49
# Timestep: 128000, episode reward (moving average, 20 episodes): -231.0
# Timestep: 129000, episode reward (moving average, 20 episodes): -231.57
# Timestep: 130000, episode reward (moving average, 20 episodes): -225.86
# Timestep: 131000, episode reward (moving average, 20 episodes): -233.14
# Timestep: 132000, episode reward (moving average, 20 episodes): -255.48
# Timestep: 133000, episode reward (moving average, 20 episodes): -252.33
# Timestep: 134000, episode reward (moving average, 20 episodes): -248.14
# Timestep: 135000, episode reward (moving average, 20 episodes): -242.58
# Timestep: 136000, episode reward (moving average, 20 episodes): -243.86
# Timestep: 137000, episode reward (moving average, 20 episodes): -236.5
# Timestep: 138000, episode reward (moving average, 20 episodes): -210.62
# Timestep: 139000, episode reward (moving average, 20 episodes): -214.02
# Timestep: 140000, episode reward (moving average, 20 episodes): -215.36
# Timestep: 141000, episode reward (moving average, 20 episodes): -200.76
# Timestep: 142000, episode reward (moving average, 20 episodes): -212.92
# Timestep: 143000, episode reward (moving average, 20 episodes): -212.88
# Timestep: 144000, episode reward (moving average, 20 episodes): -209.47
# Timestep: 145000, episode reward (moving average, 20 episodes): -208.88
# Timestep: 146000, episode reward (moving average, 20 episodes): -212.27
# Timestep: 147000, episode reward (moving average, 20 episodes): -218.46
# Timestep: 148000, episode reward (moving average, 20 episodes): -204.39
# Timestep: 149000, episode reward (moving average, 20 episodes): -194.81
# Timestep: 150000, episode reward (moving average, 20 episodes): -186.84
# Timestep: 151000, episode reward (moving average, 20 episodes): -186.45
# Timestep: 152000, episode reward (moving average, 20 episodes): -250.55
# Timestep: 153000, episode reward (moving average, 20 episodes): -241.95
# Timestep: 154000, episode reward (moving average, 20 episodes): -235.93
# Timestep: 155000, episode reward (moving average, 20 episodes): -227.59
# Timestep: 156000, episode reward (moving average, 20 episodes): -222.9
# Timestep: 157000, episode reward (moving average, 20 episodes): -227.11
# Timestep: 158000, episode reward (moving average, 20 episodes): -223.49
# Timestep: 159000, episode reward (moving average, 20 episodes): -242.51
# Timestep: 160000, episode reward (moving average, 20 episodes): -236.81
# Timestep: 161000, episode reward (moving average, 20 episodes): -245.59
# Timestep: 162000, episode reward (moving average, 20 episodes): -309.42
# Timestep: 163000, episode reward (moving average, 20 episodes): -258.15
# Timestep: 164000, episode reward (moving average, 20 episodes): -299.38
# Timestep: 165000, episode reward (moving average, 20 episodes): -332.72
# Timestep: 166000, episode reward (moving average, 20 episodes): -312.47
# Timestep: 167000, episode reward (moving average, 20 episodes): -326.7
# Timestep: 168000, episode reward (moving average, 20 episodes): -292.09
# Timestep: 169000, episode reward (moving average, 20 episodes): -278.06
# Timestep: 170000, episode reward (moving average, 20 episodes): -328.98
# Timestep: 171000, episode reward (moving average, 20 episodes): -343.29
# Timestep: 172000, episode reward (moving average, 20 episodes): -305.48
# Timestep: 173000, episode reward (moving average, 20 episodes): -326.69
# Timestep: 174000, episode reward (moving average, 20 episodes): -399.68
# Timestep: 175000, episode reward (moving average, 20 episodes): -406.59
# Timestep: 176000, episode reward (moving average, 20 episodes): -383.54
# Timestep: 177000, episode reward (moving average, 20 episodes): -358.55
# Timestep: 178000, episode reward (moving average, 20 episodes): -344.19
# Timestep: 179000, episode reward (moving average, 20 episodes): -355.04
# Timestep: 180000, episode reward (moving average, 20 episodes): -303.74
# Timestep: 181000, episode reward (moving average, 20 episodes): -266.57
# Timestep: 182000, episode reward (moving average, 20 episodes): -254.22
# Timestep: 183000, episode reward (moving average, 20 episodes): -256.81
# Timestep: 184000, episode reward (moving average, 20 episodes): -250.34
# Timestep: 185000, episode reward (moving average, 20 episodes): -246.93
# Timestep: 186000, episode reward (moving average, 20 episodes): -253.24
# Timestep: 187000, episode reward (moving average, 20 episodes): -238.81
# Timestep: 188000, episode reward (moving average, 20 episodes): -234.13
# Timestep: 189000, episode reward (moving average, 20 episodes): -227.12
# Timestep: 190000, episode reward (moving average, 20 episodes): -226.61
# Timestep: 191000, episode reward (moving average, 20 episodes): -227.12
# Timestep: 192000, episode reward (moving average, 20 episodes): -214.35
# Timestep: 193000, episode reward (moving average, 20 episodes): -215.95
# Timestep: 194000, episode reward (moving average, 20 episodes): -208.48
# Timestep: 195000, episode reward (moving average, 20 episodes): -195.4
# Timestep: 196000, episode reward (moving average, 20 episodes): -200.22
# Timestep: 197000, episode reward (moving average, 20 episodes): -192.13
# Timestep: 198000, episode reward (moving average, 20 episodes): -191.6
# Timestep: 199000, episode reward (moving average, 20 episodes): -213.37
# Timestep: 200000, episode reward (moving average, 20 episodes): -248.42
# Timestep: 201000, episode reward (moving average, 20 episodes): -244.78
# Timestep: 202000, episode reward (moving average, 20 episodes): -227.15
# Timestep: 203000, episode reward (moving average, 20 episodes): -231.41
# Timestep: 204000, episode reward (moving average, 20 episodes): -239.16
# Timestep: 205000, episode reward (moving average, 20 episodes): -232.38
# Timestep: 206000, episode reward (moving average, 20 episodes): -237.58
# Timestep: 207000, episode reward (moving average, 20 episodes): -235.93
# Timestep: 208000, episode reward (moving average, 20 episodes): -252.27
# Timestep: 209000, episode reward (moving average, 20 episodes): -257.5
# Timestep: 210000, episode reward (moving average, 20 episodes): -273.57
# Timestep: 211000, episode reward (moving average, 20 episodes): -243.7
# Timestep: 212000, episode reward (moving average, 20 episodes): -215.18
# Timestep: 213000, episode reward (moving average, 20 episodes): -224.71
# Timestep: 214000, episode reward (moving average, 20 episodes): -227.99
# Timestep: 215000, episode reward (moving average, 20 episodes): -230.12
# Timestep: 216000, episode reward (moving average, 20 episodes): -224.23
# Timestep: 217000, episode reward (moving average, 20 episodes): -221.33
# Timestep: 218000, episode reward (moving average, 20 episodes): -246.04
# Timestep: 219000, episode reward (moving average, 20 episodes): -268.83
# Timestep: 220000, episode reward (moving average, 20 episodes): -262.13
# Timestep: 221000, episode reward (moving average, 20 episodes): -259.9
# Timestep: 222000, episode reward (moving average, 20 episodes): -264.7
# Timestep: 223000, episode reward (moving average, 20 episodes): -254.65
# Timestep: 224000, episode reward (moving average, 20 episodes): -251.26
# Timestep: 225000, episode reward (moving average, 20 episodes): -226.12
# Timestep: 226000, episode reward (moving average, 20 episodes): -228.09
# Timestep: 227000, episode reward (moving average, 20 episodes): -221.14
# Timestep: 228000, episode reward (moving average, 20 episodes): -214.91
# Timestep: 229000, episode reward (moving average, 20 episodes): -213.02
# Timestep: 230000, episode reward (moving average, 20 episodes): -207.55
# Timestep: 231000, episode reward (moving average, 20 episodes): -192.84
# Timestep: 232000, episode reward (moving average, 20 episodes): -193.39
# Timestep: 233000, episode reward (moving average, 20 episodes): -185.0
# Timestep: 234000, episode reward (moving average, 20 episodes): -182.91
# Timestep: 235000, episode reward (moving average, 20 episodes): -159.23
# Timestep: 236000, episode reward (moving average, 20 episodes): -136.76
# Timestep: 237000, episode reward (moving average, 20 episodes): -135.6
# Timestep: 238000, episode reward (moving average, 20 episodes): -132.54
# Timestep: 239000, episode reward (moving average, 20 episodes): -132.56
# Timestep: 240000, episode reward (moving average, 20 episodes): -131.68
# Timestep: 241000, episode reward (moving average, 20 episodes): -127.98
# Timestep: 242000, episode reward (moving average, 20 episodes): -116.1
# Timestep: 243000, episode reward (moving average, 20 episodes): -109.81
# Timestep: 244000, episode reward (moving average, 20 episodes): -104.54
# Timestep: 245000, episode reward (moving average, 20 episodes): -100.2
# Timestep: 246000, episode reward (moving average, 20 episodes): -112.51
# Timestep: 247000, episode reward (moving average, 20 episodes): -106.74
# Timestep: 248000, episode reward (moving average, 20 episodes): -116.82
# Timestep: 249000, episode reward (moving average, 20 episodes): -138.02
# Timestep: 250000, episode reward (moving average, 20 episodes): -117.05
# Timestep: 251000, episode reward (moving average, 20 episodes): -126.91
# Timestep: 252000, episode reward (moving average, 20 episodes): -151.36
# Timestep: 253000, episode reward (moving average, 20 episodes): -163.39
# Timestep: 254000, episode reward (moving average, 20 episodes): -163.0
# Timestep: 255000, episode reward (moving average, 20 episodes): -156.52
# Timestep: 256000, episode reward (moving average, 20 episodes): -154.63
# Timestep: 257000, episode reward (moving average, 20 episodes): -157.17
# Timestep: 258000, episode reward (moving average, 20 episodes): -162.89
# Timestep: 259000, episode reward (moving average, 20 episodes): -170.91
# Timestep: 260000, episode reward (moving average, 20 episodes): -170.2
# Timestep: 261000, episode reward (moving average, 20 episodes): -161.4
# Timestep: 262000, episode reward (moving average, 20 episodes): -148.52
# Timestep: 263000, episode reward (moving average, 20 episodes): -160.7
# Timestep: 264000, episode reward (moving average, 20 episodes): -150.47
# Timestep: 265000, episode reward (moving average, 20 episodes): -155.74
# Timestep: 266000, episode reward (moving average, 20 episodes): -130.35
# Timestep: 267000, episode reward (moving average, 20 episodes): -162.07
# Timestep: 268000, episode reward (moving average, 20 episodes): -148.02
# Timestep: 269000, episode reward (moving average, 20 episodes): -147.7
# Timestep: 270000, episode reward (moving average, 20 episodes): -135.48
# Timestep: 271000, episode reward (moving average, 20 episodes): -146.96
# Timestep: 272000, episode reward (moving average, 20 episodes): -139.38
# Timestep: 273000, episode reward (moving average, 20 episodes): -142.52
# Timestep: 274000, episode reward (moving average, 20 episodes): -147.39
# Timestep: 275000, episode reward (moving average, 20 episodes): -146.62
# Timestep: 276000, episode reward (moving average, 20 episodes): -140.34
# Timestep: 277000, episode reward (moving average, 20 episodes): -128.79
# Timestep: 278000, episode reward (moving average, 20 episodes): -143.75
# Timestep: 279000, episode reward (moving average, 20 episodes): -141.37
# Timestep: 280000, episode reward (moving average, 20 episodes): -139.36
# Timestep: 281000, episode reward (moving average, 20 episodes): -164.57
# Timestep: 282000, episode reward (moving average, 20 episodes): -178.04
# Timestep: 283000, episode reward (moving average, 20 episodes): -183.31
# Timestep: 284000, episode reward (moving average, 20 episodes): -166.05
# Timestep: 285000, episode reward (moving average, 20 episodes): -190.39
# Timestep: 286000, episode reward (moving average, 20 episodes): -191.84
# Timestep: 287000, episode reward (moving average, 20 episodes): -183.16
# Timestep: 288000, episode reward (moving average, 20 episodes): -170.95
# Timestep: 289000, episode reward (moving average, 20 episodes): -175.43
# Timestep: 290000, episode reward (moving average, 20 episodes): -175.42
# Timestep: 291000, episode reward (moving average, 20 episodes): -176.66
# Timestep: 292000, episode reward (moving average, 20 episodes): -196.72
# Timestep: 293000, episode reward (moving average, 20 episodes): -202.93
# Timestep: 294000, episode reward (moving average, 20 episodes): -213.31
# Timestep: 295000, episode reward (moving average, 20 episodes): -211.89
# Timestep: 296000, episode reward (moving average, 20 episodes): -216.47
# Timestep: 297000, episode reward (moving average, 20 episodes): -224.98
# Timestep: 298000, episode reward (moving average, 20 episodes): -213.34
# Timestep: 299000, episode reward (moving average, 20 episodes): -176.98
# Timestep: 300000, episode reward (moving average, 20 episodes): -183.9
# Timestep: 1000, episode reward (moving average, 20 episodes): -141.16
# Timestep: 2000, episode reward (moving average, 20 episodes): -210.0
# Timestep: 3000, episode reward (moving average, 20 episodes): -215.17
# Timestep: 4000, episode reward (moving average, 20 episodes): -238.13
# Timestep: 5000, episode reward (moving average, 20 episodes): -259.66
# Timestep: 6000, episode reward (moving average, 20 episodes): -258.73
# Timestep: 7000, episode reward (moving average, 20 episodes): -229.44
# Timestep: 8000, episode reward (moving average, 20 episodes): -242.82
# Timestep: 9000, episode reward (moving average, 20 episodes): -213.61
# Timestep: 10000, episode reward (moving average, 20 episodes): -208.0
# Timestep: 11000, episode reward (moving average, 20 episodes): -206.01
# Timestep: 12000, episode reward (moving average, 20 episodes): -209.14
# Timestep: 13000, episode reward (moving average, 20 episodes): -175.91
# Timestep: 14000, episode reward (moving average, 20 episodes): -179.06
# Timestep: 15000, episode reward (moving average, 20 episodes): -188.29
# Timestep: 16000, episode reward (moving average, 20 episodes): -199.24
# Timestep: 17000, episode reward (moving average, 20 episodes): -203.91
# Timestep: 18000, episode reward (moving average, 20 episodes): -211.46
# Timestep: 19000, episode reward (moving average, 20 episodes): -230.14
# Timestep: 20000, episode reward (moving average, 20 episodes): -235.9
# Timestep: 21000, episode reward (moving average, 20 episodes): -208.89
# Timestep: 22000, episode reward (moving average, 20 episodes): -192.04
# Timestep: 23000, episode reward (moving average, 20 episodes): -149.17
# Timestep: 24000, episode reward (moving average, 20 episodes): -149.05
# Timestep: 25000, episode reward (moving average, 20 episodes): -150.04
# Timestep: 26000, episode reward (moving average, 20 episodes): -141.16
# Timestep: 27000, episode reward (moving average, 20 episodes): -134.43
# Timestep: 28000, episode reward (moving average, 20 episodes): -126.74
# Timestep: 29000, episode reward (moving average, 20 episodes): -113.12
# Timestep: 30000, episode reward (moving average, 20 episodes): -108.26
# Timestep: 31000, episode reward (moving average, 20 episodes): -113.16
# Timestep: 32000, episode reward (moving average, 20 episodes): -104.87
# Timestep: 33000, episode reward (moving average, 20 episodes): -113.44
# Timestep: 34000, episode reward (moving average, 20 episodes): -107.86
# Timestep: 35000, episode reward (moving average, 20 episodes): -116.96
# Timestep: 36000, episode reward (moving average, 20 episodes): -128.12
# Timestep: 37000, episode reward (moving average, 20 episodes): -119.98
# Timestep: 38000, episode reward (moving average, 20 episodes): -112.84
# Timestep: 39000, episode reward (moving average, 20 episodes): -126.5
# Timestep: 40000, episode reward (moving average, 20 episodes): -132.99
# Timestep: 41000, episode reward (moving average, 20 episodes): -148.22
# Timestep: 42000, episode reward (moving average, 20 episodes): -157.54
# Timestep: 43000, episode reward (moving average, 20 episodes): -160.59
# Timestep: 44000, episode reward (moving average, 20 episodes): -160.07
# Timestep: 45000, episode reward (moving average, 20 episodes): -165.2
# Timestep: 46000, episode reward (moving average, 20 episodes): -178.93
# Timestep: 47000, episode reward (moving average, 20 episodes): -188.88
# Timestep: 48000, episode reward (moving average, 20 episodes): -184.65
# Timestep: 49000, episode reward (moving average, 20 episodes): -164.53
# Timestep: 50000, episode reward (moving average, 20 episodes): -133.8
# Timestep: 51000, episode reward (moving average, 20 episodes): -122.87
# Timestep: 52000, episode reward (moving average, 20 episodes): -113.84
# Timestep: 53000, episode reward (moving average, 20 episodes): -116.76
# Timestep: 54000, episode reward (moving average, 20 episodes): -105.52
# Timestep: 55000, episode reward (moving average, 20 episodes): -105.27
# Timestep: 56000, episode reward (moving average, 20 episodes): -106.69
# Timestep: 57000, episode reward (moving average, 20 episodes): -105.58
# Timestep: 58000, episode reward (moving average, 20 episodes): -109.67
# Timestep: 59000, episode reward (moving average, 20 episodes): -120.35
# Timestep: 60000, episode reward (moving average, 20 episodes): -132.26
# Timestep: 61000, episode reward (moving average, 20 episodes): -134.6
# Timestep: 62000, episode reward (moving average, 20 episodes): -129.27
# Timestep: 63000, episode reward (moving average, 20 episodes): -133.43
# Timestep: 64000, episode reward (moving average, 20 episodes): -142.25
# Timestep: 65000, episode reward (moving average, 20 episodes): -153.52
# Timestep: 66000, episode reward (moving average, 20 episodes): -156.84
# Timestep: 67000, episode reward (moving average, 20 episodes): -170.35
# Timestep: 68000, episode reward (moving average, 20 episodes): -175.12
# Timestep: 69000, episode reward (moving average, 20 episodes): -183.84
# Timestep: 70000, episode reward (moving average, 20 episodes): -192.76
# Timestep: 71000, episode reward (moving average, 20 episodes): -192.03
# Timestep: 72000, episode reward (moving average, 20 episodes): -195.45
# Timestep: 73000, episode reward (moving average, 20 episodes): -192.06
# ...
# Timestep: 77000, episode reward (moving average, 20 episodes): -76.43
# Timestep: 78000, episode reward (moving average, 20 episodes): -45.53
# Timestep: 79000, episode reward (moving average, 20 episodes): -6.54
# Timestep: 80000, episode reward (moving average, 20 episodes): -4.15
# Timestep: 81000, episode reward (moving average, 20 episodes): -17.96
# Timestep: 82000, episode reward (moving average, 20 episodes): -15.68
# Timestep: 83000, episode reward (moving average, 20 episodes): -32.16
# Timestep: 84000, episode reward (moving average, 20 episodes): -25.38
# Timestep: 85000, episode reward (moving average, 20 episodes): -29.53
# Timestep: 86000, episode reward (moving average, 20 episodes): -41.87
# Timestep: 87000, episode reward (moving average, 20 episodes): -34.44
# Timestep: 88000, episode reward (moving average, 20 episodes): -47.0
# Timestep: 89000, episode reward (moving average, 20 episodes): -36.11
# Timestep: 90000, episode reward (moving average, 20 episodes): -49.15
# Timestep: 91000, episode reward (moving average, 20 episodes): -47.36
# Timestep: 92000, episode reward (moving average, 20 episodes): -53.05
# Timestep: 93000, episode reward (moving average, 20 episodes): -49.65
# Timestep: 94000, episode reward (moving average, 20 episodes): -48.47
# Timestep: 95000, episode reward (moving average, 20 episodes): -62.85
# Timestep: 96000, episode reward (moving average, 20 episodes): -59.95
# Timestep: 97000, episode reward (moving average, 20 episodes): -73.51
# Timestep: 98000, episode reward (moving average, 20 episodes): -88.11
# Timestep: 99000, episode reward (moving average, 20 episodes): -90.92
# Timestep: 100000, episode reward (moving average, 20 episodes): -107.0
# Timestep: 101000, episode reward (moving average, 20 episodes): -106.63
# Timestep: 102000, episode reward (moving average, 20 episodes): -101.3
# Timestep: 103000, episode reward (moving average, 20 episodes): -103.48
# Timestep: 104000, episode reward (moving average, 20 episodes): -98.28
# Timestep: 105000, episode reward (moving average, 20 episodes): -103.38
# Timestep: 106000, episode reward (moving average, 20 episodes): -103.96
# Timestep: 107000, episode reward (moving average, 20 episodes): -107.48
# Timestep: 108000, episode reward (moving average, 20 episodes): -107.15
# Timestep: 109000, episode reward (moving average, 20 episodes): -103.75
# Timestep: 110000, episode reward (moving average, 20 episodes): -100.14
# Timestep: 111000, episode reward (moving average, 20 episodes): -85.09
# Timestep: 112000, episode reward (moving average, 20 episodes): -74.95
# Timestep: 113000, episode reward (moving average, 20 episodes): -71.61
# Timestep: 114000, episode reward (moving average, 20 episodes): -67.03
# Timestep: 115000, episode reward (moving average, 20 episodes): -66.99
# Timestep: 116000, episode reward (moving average, 20 episodes): -74.97
# Timestep: 117000, episode reward (moving average, 20 episodes): -71.74
# Timestep: 118000, episode reward (moving average, 20 episodes): -98.18
# Timestep: 119000, episode reward (moving average, 20 episodes): -87.39
# Timestep: 120000, episode reward (moving average, 20 episodes): -107.08
# Timestep: 121000, episode reward (moving average, 20 episodes): -105.44
# Timestep: 122000, episode reward (moving average, 20 episodes): -100.31
# Timestep: 123000, episode reward (moving average, 20 episodes): -96.72
# Timestep: 124000, episode reward (moving average, 20 episodes): -97.89
# Timestep: 125000, episode reward (moving average, 20 episodes): -99.89
# Timestep: 126000, episode reward (moving average, 20 episodes): -103.47
# Timestep: 127000, episode reward (moving average, 20 episodes): -113.65
# Timestep: 128000, episode reward (moving average, 20 episodes): -115.78
# Timestep: 129000, episode reward (moving average, 20 episodes): -116.34
# Timestep: 130000, episode reward (moving average, 20 episodes): -116.22
# Timestep: 131000, episode reward (moving average, 20 episodes): -108.63
# Timestep: 132000, episode reward (moving average, 20 episodes): -109.18
# Timestep: 133000, episode reward (moving average, 20 episodes): -110.44
# Timestep: 134000, episode reward (moving average, 20 episodes): -96.33
# Timestep: 135000, episode reward (moving average, 20 episodes): -83.79
# Timestep: 136000, episode reward (moving average, 20 episodes): -84.82
# Timestep: 137000, episode reward (moving average, 20 episodes): -101.56
# Timestep: 138000, episode reward (moving average, 20 episodes): -115.16
# Timestep: 139000, episode reward (moving average, 20 episodes): -117.7
# Timestep: 140000, episode reward (moving average, 20 episodes): -123.64
# Timestep: 141000, episode reward (moving average, 20 episodes): -117.45
# Timestep: 142000, episode reward (moving average, 20 episodes): -117.27
# Timestep: 143000, episode reward (moving average, 20 episodes): -121.07
# Timestep: 144000, episode reward (moving average, 20 episodes): -123.42
# Timestep: 145000, episode reward (moving average, 20 episodes): -128.78
# Timestep: 146000, episode reward (moving average, 20 episodes): -123.37
# Timestep: 147000, episode reward (moving average, 20 episodes): -113.89
# Timestep: 148000, episode reward (moving average, 20 episodes): -115.01
# Timestep: 149000, episode reward (moving average, 20 episodes): -117.26
# Timestep: 150000, episode reward (moving average, 20 episodes): -127.11
# Timestep: 151000, episode reward (moving average, 20 episodes): -126.46
# Timestep: 152000, episode reward (moving average, 20 episodes): -125.17
# Timestep: 153000, episode reward (moving average, 20 episodes): -118.59
# Timestep: 154000, episode reward (moving average, 20 episodes): -88.15
# Timestep: 155000, episode reward (moving average, 20 episodes): -85.86
# Timestep: 156000, episode reward (moving average, 20 episodes): -96.58
# Timestep: 157000, episode reward (moving average, 20 episodes): -102.19
# Timestep: 158000, episode reward (moving average, 20 episodes): -92.43
# Timestep: 159000, episode reward (moving average, 20 episodes): -87.35
# Timestep: 160000, episode reward (moving average, 20 episodes): -71.02
# Timestep: 161000, episode reward (moving average, 20 episodes): -77.37
# Timestep: 162000, episode reward (moving average, 20 episodes): -77.77
# Timestep: 163000, episode reward (moving average, 20 episodes): -62.84
# Timestep: 164000, episode reward (moving average, 20 episodes): -59.35
# Timestep: 165000, episode reward (moving average, 20 episodes): -44.31
# Timestep: 166000, episode reward (moving average, 20 episodes): -53.06
# Timestep: 167000, episode reward (moving average, 20 episodes): -45.1
# Timestep: 168000, episode reward (moving average, 20 episodes): -12.62
# Timestep: 169000, episode reward (moving average, 20 episodes): -5.28
# Timestep: 170000, episode reward (moving average, 20 episodes): 1.14
# Timestep: 171000, episode reward (moving average, 20 episodes): 23.66
# Timestep: 172000, episode reward (moving average, 20 episodes): 2.63
# Timestep: 173000, episode reward (moving average, 20 episodes): 7.93
# Timestep: 174000, episode reward (moving average, 20 episodes): 10.73
# Timestep: 175000, episode reward (moving average, 20 episodes): 1.72
# Timestep: 176000, episode reward (moving average, 20 episodes): 10.49
# Timestep: 177000, episode reward (moving average, 20 episodes): 11.19
# Timestep: 178000, episode reward (moving average, 20 episodes): 0.27
# Timestep: 179000, episode reward (moving average, 20 episodes): 0.34
# Timestep: 180000, episode reward (moving average, 20 episodes): 3.28
# Timestep: 181000, episode reward (moving average, 20 episodes): 0.24
# Timestep: 182000, episode reward (moving average, 20 episodes): -0.39
# Timestep: 183000, episode reward (moving average, 20 episodes): -6.07
# Timestep: 184000, episode reward (moving average, 20 episodes): -12.67
# Timestep: 185000, episode reward (moving average, 20 episodes): -28.56
# Timestep: 186000, episode reward (moving average, 20 episodes): -50.48
# Timestep: 187000, episode reward (moving average, 20 episodes): -62.93
# Timestep: 188000, episode reward (moving average, 20 episodes): -66.87
# Timestep: 189000, episode reward (moving average, 20 episodes): -75.69
# Timestep: 190000, episode reward (moving average, 20 episodes): -84.99
# Timestep: 191000, episode reward (moving average, 20 episodes): -78.13
# Timestep: 192000, episode reward (moving average, 20 episodes): -88.46
# Timestep: 193000, episode reward (moving average, 20 episodes): -89.75
# Timestep: 194000, episode reward (moving average, 20 episodes): -105.11
# Timestep: 195000, episode reward (moving average, 20 episodes): -108.21
# Timestep: 196000, episode reward (moving average, 20 episodes): -107.61
# Timestep: 197000, episode reward (moving average, 20 episodes): -117.96
# Timestep: 198000, episode reward (moving average, 20 episodes): -121.94
# Timestep: 199000, episode reward (moving average, 20 episodes): -135.85
# Timestep: 200000, episode reward (moving average, 20 episodes): -139.12
# Timestep: 201000, episode reward (moving average, 20 episodes): -144.59
# Timestep: 202000, episode reward (moving average, 20 episodes): -126.76
# Timestep: 203000, episode reward (moving average, 20 episodes): -128.54
# Timestep: 204000, episode reward (moving average, 20 episodes): -128.51
# Timestep: 205000, episode reward (moving average, 20 episodes): -121.27
# Timestep: 206000, episode reward (moving average, 20 episodes): -121.66
# Timestep: 207000, episode reward (moving average, 20 episodes): -102.49
# Timestep: 208000, episode reward (moving average, 20 episodes): -102.26
# Timestep: 209000, episode reward (moving average, 20 episodes): -101.86
# Timestep: 210000, episode reward (moving average, 20 episodes): -96.36
# Timestep: 211000, episode reward (moving average, 20 episodes): -97.81
# Timestep: 212000, episode reward (moving average, 20 episodes): -121.96
# Timestep: 213000, episode reward (moving average, 20 episodes): -144.91
# Timestep: 214000, episode reward (moving average, 20 episodes): -148.98
# Timestep: 215000, episode reward (moving average, 20 episodes): -153.35
# Timestep: 216000, episode reward (moving average, 20 episodes): -161.71
# Timestep: 217000, episode reward (moving average, 20 episodes): -173.27
# Timestep: 218000, episode reward (moving average, 20 episodes): -177.03
# Timestep: 219000, episode reward (moving average, 20 episodes): -180.07
# Timestep: 220000, episode reward (moving average, 20 episodes): -182.62
# Timestep: 221000, episode reward (moving average, 20 episodes): -195.13
# Timestep: 222000, episode reward (moving average, 20 episodes): -202.59
# Timestep: 223000, episode reward (moving average, 20 episodes): -197.69
# Timestep: 224000, episode reward (moving average, 20 episodes): -189.6
# Timestep: 225000, episode reward (moving average, 20 episodes): -180.26
# Timestep: 226000, episode reward (moving average, 20 episodes): -174.23
# Timestep: 227000, episode reward (moving average, 20 episodes): -165.48
# Timestep: 228000, episode reward (moving average, 20 episodes): -148.0
# Timestep: 229000, episode reward (moving average, 20 episodes): -133.64
# Timestep: 230000, episode reward (moving average, 20 episodes): -122.57
# Timestep: 231000, episode reward (moving average, 20 episodes): -116.0
# Timestep: 232000, episode reward (moving average, 20 episodes): -107.34
# Timestep: 233000, episode reward (moving average, 20 episodes): -101.26
# Timestep: 234000, episode reward (moving average, 20 episodes): -93.73
# Timestep: 235000, episode reward (moving average, 20 episodes): -88.69
# Timestep: 236000, episode reward (moving average, 20 episodes): -88.45
# Timestep: 237000, episode reward (moving average, 20 episodes): -84.28
# Timestep: 238000, episode reward (moving average, 20 episodes): -78.44
# Timestep: 239000, episode reward (moving average, 20 episodes): -74.39
# Timestep: 240000, episode reward (moving average, 20 episodes): -71.79
# Timestep: 241000, episode reward (moving average, 20 episodes): -70.14
# Timestep: 242000, episode reward (moving average, 20 episodes): -65.38
# Timestep: 243000, episode reward (moving average, 20 episodes): -65.92
# Timestep: 244000, episode reward (moving average, 20 episodes): -63.92
# Timestep: 245000, episode reward (moving average, 20 episodes): -57.96
# Timestep: 246000, episode reward (moving average, 20 episodes): -64.98
# Timestep: 247000, episode reward (moving average, 20 episodes): -64.49
# Timestep: 248000, episode reward (moving average, 20 episodes): -60.18
# Timestep: 249000, episode reward (moving average, 20 episodes): -57.98
# Timestep: 250000, episode reward (moving average, 20 episodes): -56.83
# Timestep: 251000, episode reward (moving average, 20 episodes): -55.35
# Timestep: 252000, episode reward (moving average, 20 episodes): -56.94
# Timestep: 253000, episode reward (moving average, 20 episodes): -55.62
# Timestep: 254000, episode reward (moving average, 20 episodes): -56.83
# Timestep: 255000, episode reward (moving average, 20 episodes): -59.26
# Timestep: 256000, episode reward (moving average, 20 episodes): -65.12
# Timestep: 257000, episode reward (moving average, 20 episodes): -63.66
# Timestep: 258000, episode reward (moving average, 20 episodes): -62.18
# Timestep: 259000, episode reward (moving average, 20 episodes): -60.43
# Timestep: 260000, episode reward (moving average, 20 episodes): -55.46
# Timestep: 261000, episode reward (moving average, 20 episodes): -52.77
# Timestep: 262000, episode reward (moving average, 20 episodes): -69.41
# Timestep: 263000, episode reward (moving average, 20 episodes): -74.84
# Timestep: 264000, episode reward (moving average, 20 episodes): -67.64
# Timestep: 265000, episode reward (moving average, 20 episodes): -73.69
# Timestep: 266000, episode reward (moving average, 20 episodes): -84.1
# Timestep: 267000, episode reward (moving average, 20 episodes): -97.68
# Timestep: 268000, episode reward (moving average, 20 episodes): -103.78
# Timestep: 269000, episode reward (moving average, 20 episodes): -111.56
# Timestep: 270000, episode reward (moving average, 20 episodes): -111.71
# Timestep: 271000, episode reward (moving average, 20 episodes): -120.04
# Timestep: 272000, episode reward (moving average, 20 episodes): -108.28
# Timestep: 273000, episode reward (moving average, 20 episodes): -110.07
# Timestep: 274000, episode reward (moving average, 20 episodes): -110.05
# Timestep: 275000, episode reward (moving average, 20 episodes): -124.69
# Timestep: 276000, episode reward (moving average, 20 episodes): -108.45
# Timestep: 277000, episode reward (moving average, 20 episodes): -109.01
# Timestep: 278000, episode reward (moving average, 20 episodes): -100.62
# Timestep: 279000, episode reward (moving average, 20 episodes): -101.15
# Timestep: 280000, episode reward (moving average, 20 episodes): -93.1
# Timestep: 281000, episode reward (moving average, 20 episodes): -107.65
# Timestep: 282000, episode reward (moving average, 20 episodes): -109.28
# Timestep: 283000, episode reward (moving average, 20 episodes): -108.18
# Timestep: 284000, episode reward (moving average, 20 episodes): -106.89
# Timestep: 285000, episode reward (moving average, 20 episodes): -99.29
# Timestep: 286000, episode reward (moving average, 20 episodes): -107.47
# Timestep: 287000, episode reward (moving average, 20 episodes): -122.56
# Timestep: 288000, episode reward (moving average, 20 episodes): -117.75
# Timestep: 289000, episode reward (moving average, 20 episodes): -110.79
# Timestep: 290000, episode reward (moving average, 20 episodes): -111.28
# Timestep: 291000, episode reward (moving average, 20 episodes): -109.37
# Timestep: 292000, episode reward (moving average, 20 episodes): -105.14
# Timestep: 293000, episode reward (moving average, 20 episodes): -121.98
# Timestep: 294000, episode reward (moving average, 20 episodes): -121.93
# Timestep: 295000, episode reward (moving average, 20 episodes): -120.79
# Timestep: 296000, episode reward (moving average, 20 episodes): -120.32
# Timestep: 297000, episode reward (moving average, 20 episodes): -103.15
# Timestep: 298000, episode reward (moving average, 20 episodes): -91.42
# Timestep: 299000, episode reward (moving average, 20 episodes): -80.21
# Timestep: 300000, episode reward (moving average, 20 episodes): -79.84

# %%
colors = ['r', 'g', 'b', 'y', 'purple']
for i in range(5):
    agent = agents_5runs[i]
    color = colors[i]
    plt.plot(agent.list_moving_average_returns, color, label=f"of Agent ({i})")
plt.ylabel('Average Return (last 20 episodes)')
plt.xlabel('Episode#')
plt.title('Performance of the 5 Runs')
plt.ylim(-501, 300)
plt.legend()
plt.show()

# %% [markdown]
# #### Comments
#
# `Because the algorithm is based on linear logic and cannot optimize for speed, in subsequent comparisons, I reduced the total_timesteps to 3e5 to observe results more quickly.`
# `It can be observed that, most of the time, the algorithm converges, but it is not always stable.`

# %% [markdown]
# ## Point 1.3
#
# Select any one hyperparameter of the algorithm and study its effect on the agent's performance.
# You should try at least five different values of this hyperparameter and report on the observed performance. In a single plot, show the performance of the agent for different values of hyperparameter.

# %%
learning_rates = [
    (0.0001, 0.0001),
    (0.0002, 0.0003),
    (0.001, 0.0003),
    (0.0002, 0.001),
    (0.001, 0.001),
]

agents_hyper = []
for actor_lr, critic_lr in learning_rates:
    agent = DDPG(env, total_timesteps=int(3e5), actor_lr=actor_lr, critic_lr=critic_lr)
    agent.train(make_plot=False)
    agents_hyper.append(agent)
# Out:
# Timestep: 1000, episode reward (moving average, 20 episodes): -144.93
# Timestep: 2000, episode reward (moving average, 20 episodes): -152.76
# Timestep: 3000, episode reward (moving average, 20 episodes): -132.35
# Timestep: 4000, episode reward (moving average, 20 episodes): -150.32
# Timestep: 5000, episode reward (moving average, 20 episodes): -163.04
# Timestep: 6000, episode reward (moving average, 20 episodes): -177.09
# Timestep: 7000, episode reward (moving average, 20 episodes): -174.95
# Timestep: 8000, episode reward (moving average, 20 episodes): -197.31
# Timestep: 9000, episode reward (moving average, 20 episodes): -209.32
# Timestep: 10000, episode reward (moving average, 20 episodes): -193.92
# Timestep: 11000, episode reward (moving average, 20 episodes): -162.03
# Timestep: 12000, episode reward (moving average, 20 episodes): -174.84
# Timestep: 13000, episode reward (moving average, 20 episodes): -194.83
# Timestep: 14000, episode reward (moving average, 20 episodes): -213.7
# Timestep: 15000, episode reward (moving average, 20 episodes): -182.52
# Timestep: 16000, episode reward (moving average, 20 episodes): -156.57
# Timestep: 17000, episode reward (moving average, 20 episodes): -149.54
# Timestep: 18000, episode reward (moving average, 20 episodes): -148.64
# Timestep: 19000, episode reward (moving average, 20 episodes): -178.74
# Timestep: 20000, episode reward (moving average, 20 episodes): -195.9
# Timestep: 21000, episode reward (moving average, 20 episodes): -183.3
# Timestep: 22000, episode reward (moving average, 20 episodes): -177.17
# Timestep: 23000, episode reward (moving average, 20 episodes): -186.05
# Timestep: 24000, episode reward (moving average, 20 episodes): -182.11
# Timestep: 25000, episode reward (moving average, 20 episodes): -152.81
# Timestep: 26000, episode reward (moving average, 20 episodes): -147.25
# Timestep: 27000, episode reward (moving average, 20 episodes): -139.46
# Timestep: 28000, episode reward (moving average, 20 episodes): -157.84
# Timestep: 29000, episode reward (moving average, 20 episodes): -161.49
# Timestep: 30000, episode reward (moving average, 20 episodes): -146.87
# Timestep: 31000, episode reward (moving average, 20 episodes): -132.86
# Timestep: 32000, episode reward (moving average, 20 episodes): -116.45
# Timestep: 33000, episode reward (moving average, 20 episodes): -104.85
# Timestep: 34000, episode reward (moving average, 20 episodes): -113.71
# Timestep: 35000, episode reward (moving average, 20 episodes): -137.04
# Timestep: 36000, episode reward (moving average, 20 episodes): -157.89
# Timestep: 37000, episode reward (moving average, 20 episodes): -170.57
# Timestep: 38000, episode reward (moving average, 20 episodes): -182.41
# Timestep: 39000, episode reward (moving average, 20 episodes): -187.93
# Timestep: 40000, episode reward (moving average, 20 episodes): -188.8
# Timestep: 41000, episode reward (moving average, 20 episodes): -171.98
# Timestep: 42000, episode reward (moving average, 20 episodes): -193.14
# Timestep: 43000, episode reward (moving average, 20 episodes): -198.65
# Timestep: 44000, episode reward (moving average, 20 episodes): -194.81
# Timestep: 45000, episode reward (moving average, 20 episodes): -192.13
# Timestep: 46000, episode reward (moving average, 20 episodes): -203.23
# Timestep: 47000, episode reward (moving average, 20 episodes): -192.91
# Timestep: 48000, episode reward (moving average, 20 episodes): -188.17
# Timestep: 49000, episode reward (moving average, 20 episodes): -203.39
# Timestep: 50000, episode reward (moving average, 20 episodes): -188.65
# Timestep: 51000, episode reward (moving average, 20 episodes): -184.38
# Timestep: 52000, episode reward (moving average, 20 episodes): -189.2
# Timestep: 53000, episode reward (moving average, 20 episodes): -185.3
# Timestep: 54000, episode reward (moving average, 20 episodes): -190.19
# Timestep: 55000, episode reward (moving average, 20 episodes): -195.45
# Timestep: 56000, episode reward (moving average, 20 episodes): -203.27
# Timestep: 57000, episode reward (moving average, 20 episodes): -214.59
# Timestep: 58000, episode reward (moving average, 20 episodes): -214.05
# Timestep: 59000, episode reward (moving average, 20 episodes): -210.39
# Timestep: 60000, episode reward (moving average, 20 episodes): -209.52
# Timestep: 61000, episode reward (moving average, 20 episodes): -189.55
# Timestep: 62000, episode reward (moving average, 20 episodes): -182.23
# Timestep: 63000, episode reward (moving average, 20 episodes): -173.0
# Timestep: 64000, episode reward (moving average, 20 episodes): -172.16
# Timestep: 65000, episode reward (moving average, 20 episodes): -163.28
# Timestep: 66000, episode reward (moving average, 20 episodes): -148.41
# Timestep: 67000, episode reward (moving average, 20 episodes): -156.5
# Timestep: 68000, episode reward (moving average, 20 episodes): -165.17
# Timestep: 69000, episode reward (moving average, 20 episodes): -182.62
# Timestep: 70000, episode reward (moving average, 20 episodes): -185.48
# Timestep: 71000, episode reward (moving average, 20 episodes): -190.46
# Timestep: 72000, episode reward (moving average, 20 episodes): -184.35
# Timestep: 73000, episode reward (moving average, 20 episodes): -192.31
# Timestep: 74000, episode reward (moving average, 20 episodes): -200.86
# Timestep: 75000, episode reward (moving average, 20 episodes): -198.75
# Timestep: 76000, episode reward (moving average, 20 episodes): -194.72
# Timestep: 77000, episode reward (moving average, 20 episodes): -199.83
# Timestep: 78000, episode reward (moving average, 20 episodes): -186.32
# Timestep: 79000, episode reward (moving average, 20 episodes): -198.29
# Timestep: 80000, episode reward (moving average, 20 episodes): -190.32
# Timestep: 81000, episode reward (moving average, 20 episodes): -186.4
# Timestep: 82000, episode reward (moving average, 20 episodes): -190.47
# Timestep: 83000, episode reward (moving average, 20 episodes): -187.04
# Timestep: 84000, episode reward (moving average, 20 episodes): -180.91
# Timestep: 85000, episode reward (moving average, 20 episodes): -179.75
# Timestep: 86000, episode reward (moving average, 20 episodes): -187.34
# Timestep: 87000, episode reward (moving average, 20 episodes): -199.78
# Timestep: 88000, episode reward (moving average, 20 episodes): -199.71
# Timestep: 89000, episode reward (moving average, 20 episodes): -192.79
# Timestep: 90000, episode reward (moving average, 20 episodes): -185.19
# Timestep: 91000, episode reward (moving average, 20 episodes): -183.46
# Timestep: 92000, episode reward (moving average, 20 episodes): -188.96
# Timestep: 93000, episode reward (moving average, 20 episodes): -182.09
# Timestep: 94000, episode reward (moving average, 20 episodes): -184.8
# Timestep: 95000, episode reward (moving average, 20 episodes): -174.27
# Timestep: 96000, episode reward (moving average, 20 episodes): -167.96
# Timestep: 97000, episode reward (moving average, 20 episodes): -176.14
# Timestep: 98000, episode reward (moving average, 20 episodes): -177.72
# Timestep: 99000, episode reward (moving average, 20 episodes): -175.13
# Timestep: 100000, episode reward (moving average, 20 episodes): -175.43
# Timestep: 101000, episode reward (moving average, 20 episodes): -166.48
# Timestep: 102000, episode reward (moving average, 20 episodes): -175.72
# Timestep: 103000, episode reward (moving average, 20 episodes): -165.42
# Timestep: 104000, episode reward (moving average, 20 episodes): -163.34
# Timestep: 105000, episode reward (moving average, 20 episodes): -152.76
# Timestep: 106000, episode reward (moving average, 20 episodes): -146.99
# Timestep: 107000, episode reward (moving average, 20 episodes): -154.16
# Timestep: 108000, episode reward (moving average, 20 episodes): -163.15
# Timestep: 109000, episode reward (moving average, 20 episodes): -174.42
# Timestep: 110000, episode reward (moving average, 20 episodes): -183.92
# Timestep: 111000, episode reward (moving average, 20 episodes): -196.05
# Timestep: 112000, episode reward (moving average, 20 episodes): -208.12
# Timestep: 113000, episode reward (moving average, 20 episodes): -209.07
# Timestep: 114000, episode reward (moving average, 20 episodes): -211.33
# Timestep: 115000, episode reward (moving average, 20 episodes): -220.04
# Timestep: 116000, episode reward (moving average, 20 episodes): -212.05
# Timestep: 117000, episode reward (moving average, 20 episodes): -209.44
# Timestep: 118000, episode reward (moving average, 20 episodes): -200.39
# Timestep: 119000, episode reward (moving average, 20 episodes): -207.43
# Timestep: 120000, episode reward (moving average, 20 episodes): -210.74
# Timestep: 121000, episode reward (moving average, 20 episodes): -208.19
# Timestep: 122000, episode reward (moving average, 20 episodes): -213.82
# Timestep: 123000, episode reward (moving average, 20 episodes): -210.49
# Timestep: 124000, episode reward (moving average, 20 episodes): -205.18
# Timestep: 125000, episode reward (moving average, 20 episodes): -196.47
# Timestep: 126000, episode reward (moving average, 20 episodes): -183.2
# Timestep: 127000, episode reward (moving average, 20 episodes): -167.74
# Timestep: 128000, episode reward (moving average, 20 episodes): -159.04
# Timestep: 129000, episode reward (moving average, 20 episodes): -152.38
# Timestep: 130000, episode reward (moving average, 20 episodes): -145.69
# Timestep: 131000, episode reward (moving average, 20 episodes): -140.12
# Timestep: 132000, episode reward (moving average, 20 episodes): -132.77
# Timestep: 133000, episode reward (moving average, 20 episodes): -133.81
# Timestep: 134000, episode reward (moving average, 20 episodes): -134.17
# Timestep: 135000, episode reward (moving average, 20 episodes): -129.86
# Timestep: 136000, episode reward (moving average, 20 episodes): -124.92
# Timestep: 137000, episode reward (moving average, 20 episodes): -114.35
# Timestep: 138000, episode reward (moving average, 20 episodes): -110.41
# Timestep: 139000, episode reward (moving average, 20 episodes): -105.54
# Timestep: 140000, episode reward (moving average, 20 episodes): -102.78
# Timestep: 141000, episode reward (moving average, 20 episodes): -88.74
# Timestep: 142000, episode reward (moving average, 20 episodes): -82.2
# Timestep: 143000, episode reward (moving average, 20 episodes): -78.76
# Timestep: 144000, episode reward (moving average, 20 episodes): -74.62
# Timestep: 145000, episode reward (moving average, 20 episodes): -86.31
# Timestep: 146000, episode reward (moving average, 20 episodes): -87.63
# Timestep: 147000, episode reward (moving average, 20 episodes): -89.78
# Timestep: 148000, episode reward (moving average, 20 episodes): -89.45
# Timestep: 149000, episode reward (moving average, 20 episodes): -111.46
# Timestep: 150000, episode reward (moving average, 20 episodes): -161.45
# Timestep: 151000, episode reward (moving average, 20 episodes): -161.46
# Timestep: 152000, episode reward (moving average, 20 episodes): -162.01
# Timestep: 153000, episode reward (moving average, 20 episodes): -160.21
# Timestep: 154000, episode reward (moving average, 20 episodes): -157.67
# Timestep: 155000, episode reward (moving average, 20 episodes): -157.81
# Timestep: 156000, episode reward (moving average, 20 episodes): -159.39
# Timestep: 157000, episode reward (moving average, 20 episodes): -161.75
# Timestep: 158000, episode reward (moving average, 20 episodes): -168.01
# Timestep: 159000, episode reward (moving average, 20 episodes): -167.64
# Timestep: 160000, episode reward (moving average, 20 episodes): -168.0
# Timestep: 161000, episode reward (moving average, 20 episodes): -162.76
# Timestep: 162000, episode reward (moving average, 20 episodes): -163.56
# Timestep: 163000, episode reward (moving average, 20 episodes): -164.75
# Timestep: 164000, episode reward (moving average, 20 episodes): -164.1
# Timestep: 165000, episode reward (moving average, 20 episodes): -163.23
# Timestep: 166000, episode reward (moving average, 20 episodes): -164.0
# Timestep: 167000, episode reward (moving average, 20 episodes): -143.58
# Timestep: 168000, episode reward (moving average, 20 episodes): -118.81
# Timestep: 169000, episode reward (moving average, 20 episodes): -89.74
# Timestep: 170000, episode reward (moving average, 20 episodes): -90.75
# Timestep: 171000, episode reward (moving average, 20 episodes): -91.17
# Timestep: 172000, episode reward (moving average, 20 episodes): -92.45
# Timestep: 173000, episode reward (moving average, 20 episodes): -94.17
# Timestep: 174000, episode reward (moving average, 20 episodes): -93.67
# Timestep: 175000, episode reward (moving average, 20 episodes): -95.19
# Timestep: 176000, episode reward (moving average, 20 episodes): -90.97
# Timestep: 177000, episode reward (moving average, 20 episodes): -87.04
# Timestep: 178000, episode reward (moving average, 20 episodes): -81.48
# Timestep: 179000, episode reward (moving average, 20 episodes): -86.61
# Timestep: 180000, episode reward (moving average, 20 episodes): -79.57
# Timestep: 181000, episode reward (moving average, 20 episodes): -67.05
# Timestep: 182000, episode reward (moving average, 20 episodes): -62.77
# Timestep: 183000, episode reward (moving average, 20 episodes): -54.22
# Timestep: 184000, episode reward (moving average, 20 episodes): -55.86
# Timestep: 185000, episode reward (moving average, 20 episodes): -52.59
# Timestep: 186000, episode reward (moving average, 20 episodes): -49.56
# Timestep: 187000, episode reward (moving average, 20 episodes): -36.46
# Timestep: 188000, episode reward (moving average, 20 episodes): -28.95
# Timestep: 189000, episode reward (moving average, 20 episodes): -29.55
# Timestep: 190000, episode reward (moving average, 20 episodes): -28.45
# Timestep: 191000, episode reward (moving average, 20 episodes): -28.76
# Timestep: 192000, episode reward (moving average, 20 episodes): -25.83
# Timestep: 193000, episode reward (moving average, 20 episodes): -26.46
# Timestep: 194000, episode reward (moving average, 20 episodes): -29.58
# Timestep: 195000, episode reward (moving average, 20 episodes): -30.31
# Timestep: 196000, episode reward (moving average, 20 episodes): -31.46
# Timestep: 197000, episode reward (moving average, 20 episodes): -29.53
# Timestep: 198000, episode reward (moving average, 20 episodes): -38.45
# Timestep: 199000, episode reward (moving average, 20 episodes): -39.53
# Timestep: 200000, episode reward (moving average, 20 episodes): -38.48
# Timestep: 201000, episode reward (moving average, 20 episodes): -37.76
# Timestep: 202000, episode reward (moving average, 20 episodes): -54.38
# Timestep: 203000, episode reward (moving average, 20 episodes): -57.97
# Timestep: 204000, episode reward (moving average, 20 episodes): -63.66
# Timestep: 205000, episode reward (moving average, 20 episodes): -84.32
# Timestep: 206000, episode reward (moving average, 20 episodes): -84.53
# Timestep: 207000, episode reward (moving average, 20 episodes): -107.16
# Timestep: 208000, episode reward (moving average, 20 episodes): -104.76
# Timestep: 209000, episode reward (moving average, 20 episodes): -144.38
# Timestep: 210000, episode reward (moving average, 20 episodes): -141.18
# Timestep: 211000, episode reward (moving average, 20 episodes): -190.65
# Timestep: 212000, episode reward (moving average, 20 episodes): -243.76
# Timestep: 213000, episode reward (moving average, 20 episodes): -252.76
# Timestep: 214000, episode reward (moving average, 20 episodes): -257.08
# Timestep: 215000, episode reward (moving average, 20 episodes): -257.07
# Timestep: 216000, episode reward (moving average, 20 episodes): -249.41
# Timestep: 217000, episode reward (moving average, 20 episodes): -262.03
# Timestep: 218000, episode reward (moving average, 20 episodes): -257.54
# Timestep: 219000, episode reward (moving average, 20 episodes): -244.48
# Timestep: 220000, episode reward (moving average, 20 episodes): -231.69
# Timestep: 221000, episode reward (moving average, 20 episodes): -228.46
# Timestep: 222000, episode reward (moving average, 20 episodes): -213.26
# Timestep: 223000, episode reward (moving average, 20 episodes): -203.74
# Timestep: 224000, episode reward (moving average, 20 episodes): -201.62
# Timestep: 225000, episode reward (moving average, 20 episodes): -190.16
# Timestep: 226000, episode reward (moving average, 20 episodes): -180.42
# Timestep: 227000, episode reward (moving average, 20 episodes): -170.36
# Timestep: 228000, episode reward (moving average, 20 episodes): -170.77
# Timestep: 229000, episode reward (moving average, 20 episodes): -131.77
# Timestep: 230000, episode reward (moving average, 20 episodes): -122.2
# Timestep: 231000, episode reward (moving average, 20 episodes): -73.88
# Timestep: 232000, episode reward (moving average, 20 episodes): -62.97
# Timestep: 233000, episode reward (moving average, 20 episodes): -52.96
# Timestep: 234000, episode reward (moving average, 20 episodes): -49.49
# Timestep: 235000, episode reward (moving average, 20 episodes): -50.25
# Timestep: 236000, episode reward (moving average, 20 episodes): -47.91
# Timestep: 237000, episode reward (moving average, 20 episodes): -39.31
# Timestep: 238000, episode reward (moving average, 20 episodes): -30.93
# Timestep: 239000, episode reward (moving average, 20 episodes): -33.98
# Timestep: 240000, episode reward (moving average, 20 episodes): -35.27
# Timestep: 241000, episode reward (moving average, 20 episodes): -36.97
# Timestep: 242000, episode reward (moving average, 20 episodes): -37.76
# Timestep: 243000, episode reward (moving average, 20 episodes): -37.39
# Timestep: 244000, episode reward (moving average, 20 episodes): -35.85
# Timestep: 245000, episode reward (moving average, 20 episodes): -34.78
# Timestep: 246000, episode reward (moving average, 20 episodes): -35.3
# Timestep: 247000, episode reward (moving average, 20 episodes): -34.04
# Timestep: 248000, episode reward (moving average, 20 episodes): -34.67
# Timestep: 249000, episode reward (moving average, 20 episodes): -33.56
# Timestep: 250000, episode reward (moving average, 20 episodes): -37.76
# Timestep: 251000, episode reward (moving average, 20 episodes): -40.63
# Timestep: 252000, episode reward (moving average, 20 episodes): -39.67
# Timestep: 253000, episode reward (moving average, 20 episodes): -30.34
# Timestep: 254000, episode reward (moving average, 20 episodes): -26.84
# Timestep: 255000, episode reward (moving average, 20 episodes): -24.65
# Timestep: 256000, episode reward (moving average, 20 episodes): -20.09
# Timestep: 257000, episode reward (moving average, 20 episodes): -5.51
# Timestep: 258000, episode reward (moving average, 20 episodes): -13.94
# Timestep: 259000, episode reward (moving average, 20 episodes): -7.43
# Timestep: 260000, episode reward (moving average, 20 episodes): -5.87
# Timestep: 261000, episode reward (moving average, 20 episodes): 6.11
# Timestep: 262000, episode reward (moving average, 20 episodes): 7.97
# Timestep: 263000, episode reward (moving average, 20 episodes): 1.54
# Timestep: 264000, episode reward (moving average, 20 episodes): 5.9
# Timestep: 265000, episode reward (moving average, 20 episodes): 2.15
# Timestep: 266000, episode reward (moving average, 20 episodes): -0.14
# Timestep: 267000, episode reward (moving average, 20 episodes): 3.15
# Timestep: 268000, episode reward (moving average, 20 episodes): 2.91
# Timestep: 269000, episode reward (moving average, 20 episodes): 5.08
# Timestep: 270000, episode reward (moving average, 20 episodes): 5.95
# Timestep: 271000, episode reward (moving average, 20 episodes): -5.29
# Timestep: 272000, episode reward (moving average, 20 episodes): -18.11
# Timestep: 273000, episode reward (moving average, 20 episodes): -28.8
# Timestep: 274000, episode reward (moving average, 20 episodes): -35.49
# Timestep: 275000, episode reward (moving average, 20 episodes): -61.93
# Timestep: 276000, episode reward (moving average, 20 episodes): -77.16
# Timestep: 277000, episode reward (moving average, 20 episodes): -80.32
# Timestep: 278000, episode reward (moving average, 20 episodes): -94.96
# Timestep: 279000, episode reward (moving average, 20 episodes): -97.41
# Timestep: 280000, episode reward (moving average, 20 episodes): -88.39
# Timestep: 281000, episode reward (moving average, 20 episodes): -91.82
# Timestep: 282000, episode reward (moving average, 20 episodes): -89.22
# Timestep: 283000, episode reward (moving average, 20 episodes): -87.12
# Timestep: 284000, episode reward (moving average, 20 episodes): -87.48
# Timestep: 285000, episode reward (moving average, 20 episodes): -88.51
# Timestep: 286000, episode reward (moving average, 20 episodes): -87.17
# Timestep: 287000, episode reward (moving average, 20 episodes): -71.82
# Timestep: 288000, episode reward (moving average, 20 episodes): -62.14
# Timestep: 289000, episode reward (moving average, 20 episodes): -67.63
# Timestep: 290000, episode reward (moving average, 20 episodes): -61.46
# Timestep: 291000, episode reward (moving average, 20 episodes): -55.98
# Timestep: 292000, episode reward (moving average, 20 episodes): -33.02
# Timestep: 293000, episode reward (moving average, 20 episodes): -21.68
# Timestep: 294000, episode reward (moving average, 20 episodes): -9.07
# Timestep: 295000, episode reward (moving average, 20 episodes): 6.15
# Timestep: 296000, episode reward (moving average, 20 episodes): -5.99
# Timestep: 297000, episode reward (moving average, 20 episodes): 1.18
# Timestep: 298000, episode reward (moving average, 20 episodes): -1.19
# Timestep: 299000, episode reward (moving average, 20 episodes): 0.36
# Timestep: 300000, episode reward (moving average, 20 episodes): -2.63
# Timestep: 1000, episode reward (moving average, 20 episodes): -165.58
# Timestep: 2000, episode reward (moving average, 20 episodes): -195.96
# Timestep: 3000, episode reward (moving average, 20 episodes): -215.82
# Timestep: 4000, episode reward (moving average, 20 episodes): -201.81
# Timestep: 5000, episode reward (moving average, 20 episodes): -199.23
# Timestep: 6000, episode reward (moving average, 20 episodes): -196.55
# Timestep: 7000, episode reward (moving average, 20 episodes): -203.42
# Timestep: 8000, episode reward (moving average, 20 episodes): -226.8
# Timestep: 9000, episode reward (moving average, 20 episodes): -236.93
# Timestep: 10000, episode reward (moving average, 20 episodes): -246.37
# Timestep: 11000, episode reward (moving average, 20 episodes): -208.8
# Timestep: 12000, episode reward (moving average, 20 episodes): -203.61
# Timestep: 13000, episode reward (moving average, 20 episodes): -184.56
# Timestep: 14000, episode reward (moving average, 20 episodes): -198.93
# Timestep: 15000, episode reward (moving average, 20 episodes): -196.74
# Timestep: 16000, episode reward (moving average, 20 episodes): -174.82
# Timestep: 17000, episode reward (moving average, 20 episodes): -175.99
# Timestep: 18000, episode reward (moving average, 20 episodes): -108.34
# Timestep: 19000, episode reward (moving average, 20 episodes): -112.13
# Timestep: 20000, episode reward (moving average, 20 episodes): -94.48
# Timestep: 21000, episode reward (moving average, 20 episodes): -96.67
# Timestep: 22000, episode reward (moving average, 20 episodes): -108.13
# Timestep: 23000, episode reward (moving average, 20 episodes): -127.07
# Timestep: 24000, episode reward (moving average, 20 episodes): -112.39
# Timestep: 25000, episode reward (moving average, 20 episodes): -109.59
# Timestep: 26000, episode reward (moving average, 20 episodes): -118.41
# Timestep: 27000, episode reward (moving average, 20 episodes): -111.94
# Timestep: 28000, episode reward (moving average, 20 episodes): -129.34
# Timestep: 29000, episode reward (moving average, 20 episodes): -143.16
# Timestep: 30000, episode reward (moving average, 20 episodes): -146.0
# Timestep: 31000, episode reward (moving average, 20 episodes): -133.85
# Timestep: 32000, episode reward (moving average, 20 episodes): -128.81
# Timestep: 33000, episode reward (moving average, 20 episodes): -123.51
# Timestep: 34000, episode reward (moving average, 20 episodes): -95.83
# Timestep: 35000, episode reward (moving average, 20 episodes): -88.88
# Timestep: 36000, episode reward (moving average, 20 episodes): -91.63
# Timestep: 37000, episode reward (moving average, 20 episodes): -90.84
# Timestep: 38000, episode reward (moving average, 20 episodes): -102.93
# Timestep: 39000, episode reward (moving average, 20 episodes): -111.14
# Timestep: 40000, episode reward (moving average, 20 episodes): -105.0
# Timestep: 41000, episode reward (moving average, 20 episodes): -116.31
# Timestep: 42000, episode reward (moving average, 20 episodes): -122.69
# Timestep: 43000, episode reward (moving average, 20 episodes): -130.28
# Timestep: 44000, episode reward (moving average, 20 episodes): -122.71
# Timestep: 45000, episode reward (moving average, 20 episodes): -114.04
# Timestep: 46000, episode reward (moving average, 20 episodes): -123.55
# Timestep: 47000, episode reward (moving average, 20 episodes): -129.29
# Timestep: 48000, episode reward (moving average, 20 episodes): -122.41
# Timestep: 49000, episode reward (moving average, 20 episodes): -139.27
# Timestep: 50000, episode reward (moving average, 20 episodes): -132.01
# Timestep: 51000, episode reward (moving average, 20 episodes): -132.75
# Timestep: 52000, episode reward (moving average, 20 episodes): -127.48
# Timestep: 53000, episode reward (moving average, 20 episodes): -131.38
# Timestep: 54000, episode reward (moving average, 20 episodes): -136.62
# Timestep: 55000, episode reward (moving average, 20 episodes): -136.21
# Timestep: 56000, episode reward (moving average, 20 episodes): -144.92
# Timestep: 57000, episode reward (moving average, 20 episodes): -121.89
# Timestep: 58000, episode reward (moving average, 20 episodes): -118.32
# Timestep: 59000, episode reward (moving average, 20 episodes): -126.31
# Timestep: 60000, episode reward (moving average, 20 episodes): -128.98
# Timestep: 61000, episode reward (moving average, 20 episodes): -151.48
# Timestep: 62000, episode reward (moving average, 20 episodes): -150.07
# Timestep: 63000, episode reward (moving average, 20 episodes): -152.41
# Timestep: 64000, episode reward (moving average, 20 episodes): -162.7
# Timestep: 65000, episode reward (moving average, 20 episodes): -177.74
# Timestep: 66000, episode reward (moving average, 20 episodes): -170.25
# Timestep: 67000, episode reward (moving average, 20 episodes): -174.33
# Timestep: 68000, episode reward (moving average, 20 episodes): -171.99
# Timestep: 69000, episode reward (moving average, 20 episodes): -151.56
# Timestep: 70000, episode reward (moving average, 20 episodes): -147.23
# Timestep: 71000, episode reward (moving average, 20 episodes): -139.47
# Timestep: 72000, episode reward (moving average, 20 episodes): -130.68
# Timestep: 73000, episode reward (moving average, 20 episodes): -117.95
# Timestep: 74000, episode reward (moving average, 20 episodes): -103.32
# Timestep: 75000, episode reward (moving average, 20 episodes): -103.76
# Timestep: 76000, episode reward (moving average, 20 episodes): -86.66
# Timestep: 77000, episode reward (moving average, 20 episodes): -89.35
# Timestep: 78000, episode reward (moving average, 20 episodes): -89.43
# Timestep: 79000, episode reward (moving average, 20 episodes): -103.74
# Timestep: 80000, episode reward (moving average, 20 episodes): -118.82
# Timestep: 81000, episode reward (moving average, 20 episodes): -105.86
# Timestep: 82000, episode reward (moving average, 20 episodes): -111.96
# Timestep: 83000, episode reward (moving average, 20 episodes): -120.2
# Timestep: 84000, episode reward (moving average, 20 episodes): -116.3
# Timestep: 85000, episode reward (moving average, 20 episodes): -112.13
# Timestep: 86000, episode reward (moving average, 20 episodes): -122.82
# Timestep: 87000, episode reward (moving average, 20 episodes): -123.14
# Timestep: 88000, episode reward (moving average, 20 episodes): -122.56
# Timestep: 89000, episode reward (moving average, 20 episodes): -119.37
# Timestep: 90000, episode reward (moving average, 20 episodes): -117.02
# Timestep: 91000, episode reward (moving average, 20 episodes): -108.05
# Timestep: 92000, episode reward (moving average, 20 episodes): -88.14
# Timestep: 93000, episode reward (moving average, 20 episodes): -75.43
# Timestep: 94000, episode reward (moving average, 20 episodes): -77.47
# Timestep: 95000, episode reward (moving average, 20 episodes): -81.19
# Timestep: 96000, episode reward (moving average, 20 episodes): -80.09
# Timestep: 97000, episode reward (moving average, 20 episodes): -82.86
# Timestep: 98000, episode reward (moving average, 20 episodes): -89.18
# Timestep: 99000, episode reward (moving average, 20 episodes): -97.79
# Timestep: 100000, episode reward (moving average, 20 episodes): -81.8
# Timestep: 101000, episode reward (moving average, 20 episodes): -75.46
# Timestep: 102000, episode reward (moving average, 20 episodes): -75.56
# Timestep: 103000, episode reward (moving average, 20 episodes): -83.36
# Timestep: 104000, episode reward (moving average, 20 episodes): -83.43
# Timestep: 105000, episode reward (moving average, 20 episodes): -86.38
# Timestep: 106000, episode reward (moving average, 20 episodes): -80.84
# Timestep: 107000, episode reward (moving average, 20 episodes): -89.32
# Timestep: 108000, episode reward (moving average, 20 episodes): -87.5
# Timestep: 109000, episode reward (moving average, 20 episodes): -71.38
# Timestep: 110000, episode reward (moving average, 20 episodes): -70.32
# Timestep: 111000, episode reward (moving average, 20 episodes): -70.56
# Timestep: 112000, episode reward (moving average, 20 episodes): -51.7
# Timestep: 113000, episode reward (moving average, 20 episodes): -44.74
# Timestep: 114000, episode reward (moving average, 20 episodes): -46.79
# Timestep: 115000, episode reward (moving average, 20 episodes): -68.59
# Timestep: 116000, episode reward (moving average, 20 episodes): -76.33
# Timestep: 117000, episode reward (moving average, 20 episodes): -102.82
# Timestep: 118000, episode reward (moving average, 20 episodes): -94.38
# Timestep: 119000, episode reward (moving average, 20 episodes): -98.74
# Timestep: 120000, episode reward (moving average, 20 episodes): -96.09
# Timestep: 121000, episode reward (moving average, 20 episodes): -102.74
# Timestep: 122000, episode reward (moving average, 20 episodes): -89.88
# Timestep: 123000, episode reward (moving average, 20 episodes): -89.15
# Timestep: 124000, episode reward (moving average, 20 episodes): -97.65
# Timestep: 125000, episode reward (moving average, 20 episodes): -94.72
# Timestep: 126000, episode reward (moving average, 20 episodes): -91.09
# Timestep: 127000, episode reward (moving average, 20 episodes): -78.62
# Timestep: 128000, episode reward (moving average, 20 episodes): -75.6
# Timestep: 129000, episode reward (moving average, 20 episodes): -71.2
# Timestep: 130000, episode reward (moving average, 20 episodes): -64.9
# Timestep: 131000, episode reward (moving average, 20 episodes): -59.92
# Timestep: 132000, episode reward (moving average, 20 episodes): -39.63
# Timestep: 133000, episode reward (moving average, 20 episodes): -21.93
# Timestep: 134000, episode reward (moving average, 20 episodes): -15.91
# Timestep: 135000, episode reward (moving average, 20 episodes): -23.29
# Timestep: 136000, episode reward (moving average, 20 episodes): -34.43
# Timestep: 137000, episode reward (moving average, 20 episodes): -35.85
# Timestep: 138000, episode reward (moving average, 20 episodes): -36.22
# Timestep: 139000, episode reward (moving average, 20 episodes): -25.7
# Timestep: 140000, episode reward (moving average, 20 episodes): -40.36
# Timestep: 141000, episode reward (moving average, 20 episodes): -39.28
# Timestep: 142000, episode reward (moving average, 20 episodes): -56.8
# Timestep: 143000, episode reward (moving average, 20 episodes): -36.7
# Timestep: 144000, episode reward (moving average, 20 episodes): -41.21
# Timestep: 145000, episode reward (moving average, 20 episodes): -36.48
# Timestep: 146000, episode reward (moving average, 20 episodes): -31.31
# Timestep: 147000, episode reward (moving average, 20 episodes): -33.54
# Timestep: 148000, episode reward (moving average, 20 episodes): -21.97
# Timestep: 149000, episode reward (moving average, 20 episodes): -41.01
# Timestep: 150000, episode reward (moving average, 20 episodes): -51.02
# Timestep: 151000, episode reward (moving average, 20 episodes): -52.43
# Timestep: 152000, episode reward (moving average, 20 episodes): -45.79
# Timestep: 153000, episode reward (moving average, 20 episodes): -47.26
# Timestep: 154000, episode reward (moving average, 20 episodes): -47.59
# Timestep: 155000, episode reward (moving average, 20 episodes): -38.96
# Timestep: 156000, episode reward (moving average, 20 episodes): -31.06
# Timestep: 157000, episode reward (moving average, 20 episodes): -60.31
# Timestep: 158000, episode reward (moving average, 20 episodes): -57.79
# Timestep: 159000, episode reward (moving average, 20 episodes): -73.63
# Timestep: 160000, episode reward (moving average, 20 episodes): -78.52
# Timestep: 161000, episode reward (moving average, 20 episodes): -76.67
# Timestep: 162000, episode reward (moving average, 20 episodes): -77.24
# Timestep: 163000, episode reward (moving average, 20 episodes): -46.9
# Timestep: 164000, episode reward (moving average, 20 episodes): -51.44
# Timestep: 165000, episode reward (moving average, 20 episodes): -48.72
# Timestep: 166000, episode reward (moving average, 20 episodes): -59.72
# Timestep: 167000, episode reward (moving average, 20 episodes): -48.58
# Timestep: 168000, episode reward (moving average, 20 episodes): -57.09
# Timestep: 169000, episode reward (moving average, 20 episodes): -62.56
# Timestep: 170000, episode reward (moving average, 20 episodes): -49.4
# Timestep: 171000, episode reward (moving average, 20 episodes): -45.31
# Timestep: 172000, episode reward (moving average, 20 episodes): -47.92
# Timestep: 173000, episode reward (moving average, 20 episodes): -58.34
# Timestep: 174000, episode reward (moving average, 20 episodes): -59.66
# Timestep: 175000, episode reward (moving average, 20 episodes): -36.61
# Timestep: 176000, episode reward (moving average, 20 episodes): -37.31
# Timestep: 177000, episode reward (moving average, 20 episodes): -35.79
# Timestep: 178000, episode reward (moving average, 20 episodes): -32.03
# Timestep: 179000, episode reward (moving average, 20 episodes): -35.03
# Timestep: 180000, episode reward (moving average, 20 episodes): -31.63
# Timestep: 181000, episode reward (moving average, 20 episodes): -47.13
# Timestep: 182000, episode reward (moving average, 20 episodes): -19.74
# Timestep: 183000, episode reward (moving average, 20 episodes): -13.38
# Timestep: 184000, episode reward (moving average, 20 episodes): -2.22
# Timestep: 185000, episode reward (moving average, 20 episodes): -20.13
# Timestep: 186000, episode reward (moving average, 20 episodes): -21.57
# Timestep: 187000, episode reward (moving average, 20 episodes): -24.71
# Timestep: 188000, episode reward (moving average, 20 episodes): -32.79
# Timestep: 189000, episode reward (moving average, 20 episodes): -29.96
# Timestep: 190000, episode reward (moving average, 20 episodes): -40.42
# Timestep: 191000, episode reward (moving average, 20 episodes): -86.63
# Timestep: 192000, episode reward (moving average, 20 episodes): -95.2
# Timestep: 193000, episode reward (moving average, 20 episodes): -86.79
# Timestep: 194000, episode reward (moving average, 20 episodes): -78.99
# Timestep: 195000, episode reward (moving average, 20 episodes): -85.43
# Timestep: 196000, episode reward (moving average, 20 episodes): -100.94
# Timestep: 197000, episode reward (moving average, 20 episodes): -116.42
# Timestep: 198000, episode reward (moving average, 20 episodes): -88.15
# Timestep: 199000, episode reward (moving average, 20 episodes): -91.74
# Timestep: 200000, episode reward (moving average, 20 episodes): -82.43
# Timestep: 201000, episode reward (moving average, 20 episodes): -74.14
# Timestep: 202000, episode reward (moving average, 20 episodes): -92.88
# Timestep: 203000, episode reward (moving average, 20 episodes): -89.6
# Timestep: 204000, episode reward (moving average, 20 episodes): -106.1
# Timestep: 205000, episode reward (moving average, 20 episodes): -104.1
# Timestep: 206000, episode reward (moving average, 20 episodes): -93.95
# Timestep: 207000, episode reward (moving average, 20 episodes): -106.25
# Timestep: 208000, episode reward (moving average, 20 episodes): -93.91
# Timestep: 209000, episode reward (moving average, 20 episodes): -69.42
# Timestep: 210000, episode reward (moving average, 20 episodes): -70.76
# Timestep: 211000, episode reward (moving average, 20 episodes): -49.99
# Timestep: 212000, episode reward (moving average, 20 episodes): -42.86
# Timestep: 213000, episode reward (moving average, 20 episodes): -28.22
# Timestep: 214000, episode reward (moving average, 20 episodes): 10.61
# Timestep: 215000, episode reward (moving average, 20 episodes): 3.84
# Timestep: 216000, episode reward (moving average, 20 episodes): 72.45
# Timestep: 217000, episode reward (moving average, 20 episodes): 71.22
# Timestep: 218000, episode reward (moving average, 20 episodes): 67.83
# Timestep: 219000, episode reward (moving average, 20 episodes): 72.66
# Timestep: 220000, episode reward (moving average, 20 episodes): 49.96
# Timestep: 221000, episode reward (moving average, 20 episodes): 26.49
# Timestep: 222000, episode reward (moving average, 20 episodes): 28.24
# Timestep: 223000, episode reward (moving average, 20 episodes): 4.25
# Timestep: 224000, episode reward (moving average, 20 episodes): -13.56
# Timestep: 225000, episode reward (moving average, 20 episodes): -22.49
# Timestep: 226000, episode reward (moving average, 20 episodes): -0.77
# Timestep: 227000, episode reward (moving average, 20 episodes): 3.27
# Timestep: 228000, episode reward (moving average, 20 episodes): -22.37
# Timestep: 229000, episode reward (moving average, 20 episodes): -13.26
# Timestep: 230000, episode reward (moving average, 20 episodes): -57.22
# Timestep: 231000, episode reward (moving average, 20 episodes): -67.02
# Timestep: 232000, episode reward (moving average, 20 episodes): -42.85
# Timestep: 233000, episode reward (moving average, 20 episodes): -28.77
# Timestep: 234000, episode reward (moving average, 20 episodes): -21.17
# Timestep: 235000, episode reward (moving average, 20 episodes): -12.98
# Timestep: 236000, episode reward (moving average, 20 episodes): -9.91
# Timestep: 237000, episode reward (moving average, 20 episodes): 1.33
# Timestep: 238000, episode reward (moving average, 20 episodes): -9.4
# Timestep: 239000, episode reward (moving average, 20 episodes): -6.29
# Timestep: 240000, episode reward (moving average, 20 episodes): 8.17
# Timestep: 241000, episode reward (moving average, 20 episodes): -4.3
# Timestep: 242000, episode reward (moving average, 20 episodes): -3.58
# Timestep: 243000, episode reward (moving average, 20 episodes): -4.47
# Timestep: 244000, episode reward (moving average, 20 episodes): 2.48
# Timestep: 245000, episode reward (moving average, 20 episodes): -17.8
# Timestep: 246000, episode reward (moving average, 20 episodes): -67.05
# Timestep: 247000, episode reward (moving average, 20 episodes): -64.38
# Timestep: 248000, episode reward (moving average, 20 episodes): -38.74
# Timestep: 249000, episode reward (moving average, 20 episodes): -4.46
# Timestep: 250000, episode reward (moving average, 20 episodes): 25.01
# Timestep: 251000, episode reward (moving average, 20 episodes): 57.84
# Timestep: 252000, episode reward (moving average, 20 episodes): 39.92
# Timestep: 253000, episode reward (moving average, 20 episodes): 82.29
# Timestep: 254000, episode reward (moving average, 20 episodes): 107.53
# Timestep: 255000, episode reward (moving average, 20 episodes): 91.13
# Timestep: 256000, episode reward (moving average, 20 episodes): 78.32
# Timestep: 257000, episode reward (moving average, 20 episodes): 62.32
# Timestep: 258000, episode reward (moving average, 20 episodes): 38.09
# Timestep: 259000, episode reward (moving average, 20 episodes): 57.25
# Timestep: 260000, episode reward (moving average, 20 episodes): 75.43
# Timestep: 261000, episode reward (moving average, 20 episodes): 62.47
# Timestep: 262000, episode reward (moving average, 20 episodes): 34.23
# Timestep: 263000, episode reward (moving average, 20 episodes): 40.95
# Timestep: 264000, episode reward (moving average, 20 episodes): 32.92
# Timestep: 265000, episode reward (moving average, 20 episodes): 47.88
# Timestep: 266000, episode reward (moving average, 20 episodes): 66.82
# Timestep: 267000, episode reward (moving average, 20 episodes): 39.19
# Timestep: 268000, episode reward (moving average, 20 episodes): 41.81
# Timestep: 269000, episode reward (moving average, 20 episodes): 25.93
# Timestep: 270000, episode reward (moving average, 20 episodes): 57.05
# Timestep: 271000, episode reward (moving average, 20 episodes): 70.63
# Timestep: 272000, episode reward (moving average, 20 episodes): 69.63
# Timestep: 273000, episode reward (moving average, 20 episodes): 85.07
# Timestep: 274000, episode reward (moving average, 20 episodes): 70.93
# Timestep: 275000, episode reward (moving average, 20 episodes): 86.16
# Timestep: 276000, episode reward (moving average, 20 episodes): 75.3
# Timestep: 277000, episode reward (moving average, 20 episodes): 50.87
# Timestep: 278000, episode reward (moving average, 20 episodes): 52.65
# Timestep: 279000, episode reward (moving average, 20 episodes): 63.43
# Timestep: 280000, episode reward (moving average, 20 episodes): 47.61
# Timestep: 281000, episode reward (moving average, 20 episodes): 47.82
# Timestep: 282000, episode reward (moving average, 20 episodes): 35.26
# Timestep: 283000, episode reward (moving average, 20 episodes): 24.38
# Timestep: 284000, episode reward (moving average, 20 episodes): 15.96
# Timestep: 285000, episode reward (moving average, 20 episodes): 26.37
# Timestep: 286000, episode reward (moving average, 20 episodes): 10.15
# Timestep: 287000, episode reward (moving average, 20 episodes): -0.72
# Timestep: 288000, episode reward (moving average, 20 episodes): -13.5
# Timestep: 289000, episode reward (moving average, 20 episodes): -14.69
# Timestep: 290000, episode reward (moving average, 20 episodes): -28.61
# Timestep: 291000, episode reward (moving average, 20 episodes): -42.65
# Timestep: 292000, episode reward (moving average, 20 episodes): -42.43
# Timestep: 293000, episode reward (moving average, 20 episodes): -35.21
# Timestep: 294000, episode reward (moving average, 20 episodes): -49.11
# Timestep: 295000, episode reward (moving average, 20 episodes): -51.0
# Timestep: 296000, episode reward (moving average, 20 episodes): -58.89
# Timestep: 297000, episode reward (moving average, 20 episodes): -49.88
# Timestep: 298000, episode reward (moving average, 20 episodes): -63.01
# Timestep: 299000, episode reward (moving average, 20 episodes): -59.06
# Timestep: 300000, episode reward (moving average, 20 episodes): -3.11
# Timestep: 1000, episode reward (moving average, 20 episodes): -136.09
# Timestep: 2000, episode reward (moving average, 20 episodes): -193.23
# Timestep: 3000, episode reward (moving average, 20 episodes): -199.36
# Timestep: 4000, episode reward (moving average, 20 episodes): -246.54
# Timestep: 5000, episode reward (moving average, 20 episodes): -228.96
# Timestep: 6000, episode reward (moving average, 20 episodes): -229.34
# Timestep: 7000, episode reward (moving average, 20 episodes): -236.68
# Timestep: 8000, episode reward (moving average, 20 episodes): -258.7
# Timestep: 9000, episode reward (moving average, 20 episodes): -266.28
# Timestep: 10000, episode reward (moving average, 20 episodes): -268.3
# Timestep: 11000, episode reward (moving average, 20 episodes): -270.14
# Timestep: 12000, episode reward (moving average, 20 episodes): -257.78
# Timestep: 13000, episode reward (moving average, 20 episodes): -261.55
# Timestep: 14000, episode reward (moving average, 20 episodes): -227.74
# Timestep: 15000, episode reward (moving average, 20 episodes): -229.52
# Timestep: 16000, episode reward (moving average, 20 episodes): -226.7
# Timestep: 17000, episode reward (moving average, 20 episodes): -224.12
# Timestep: 18000, episode reward (moving average, 20 episodes): -171.52
# Timestep: 19000, episode reward (moving average, 20 episodes): -173.78
# Timestep: 20000, episode reward (moving average, 20 episodes): -179.24
# Timestep: 21000, episode reward (moving average, 20 episodes): -175.3
# Timestep: 22000, episode reward (moving average, 20 episodes): -192.41
# Timestep: 23000, episode reward (moving average, 20 episodes): -187.72
# Timestep: 24000, episode reward (moving average, 20 episodes): -194.84
# Timestep: 25000, episode reward (moving average, 20 episodes): -191.31
# Timestep: 26000, episode reward (moving average, 20 episodes): -192.01
# Timestep: 27000, episode reward (moving average, 20 episodes): -206.01
# Timestep: 28000, episode reward (moving average, 20 episodes): -209.69
# Timestep: 29000, episode reward (moving average, 20 episodes): -214.05
# Timestep: 30000, episode reward (moving average, 20 episodes): -201.56
# Timestep: 31000, episode reward (moving average, 20 episodes): -192.76
# Timestep: 32000, episode reward (moving average, 20 episodes): -191.96
# Timestep: 33000, episode reward (moving average, 20 episodes): -180.84
# Timestep: 34000, episode reward (moving average, 20 episodes): -181.76
# Timestep: 35000, episode reward (moving average, 20 episodes): -183.81
# Timestep: 36000, episode reward (moving average, 20 episodes): -183.01
# Timestep: 37000, episode reward (moving average, 20 episodes): -193.12
# Timestep: 38000, episode reward (moving average, 20 episodes): -193.58
# Timestep: 39000, episode reward (moving average, 20 episodes): -202.26
# Timestep: 40000, episode reward (moving average, 20 episodes): -189.61
# Timestep: 41000, episode reward (moving average, 20 episodes): -169.21
# Timestep: 42000, episode reward (moving average, 20 episodes): -168.78
# Timestep: 43000, episode reward (moving average, 20 episodes): -170.55
# Timestep: 44000, episode reward (moving average, 20 episodes): -166.1
# Timestep: 45000, episode reward (moving average, 20 episodes): -163.35
# Timestep: 46000, episode reward (moving average, 20 episodes): -159.61
# Timestep: 47000, episode reward (moving average, 20 episodes): -165.06
# Timestep: 48000, episode reward (moving average, 20 episodes): -161.91
# Timestep: 49000, episode reward (moving average, 20 episodes): -153.92
# Timestep: 50000, episode reward (moving average, 20 episodes): -153.4
# Timestep: 51000, episode reward (moving average, 20 episodes): -155.41
# Timestep: 52000, episode reward (moving average, 20 episodes): -173.88
# Timestep: 53000, episode reward (moving average, 20 episodes): -155.99
# Timestep: 54000, episode reward (moving average, 20 episodes): -159.49
# Timestep: 55000, episode reward (moving average, 20 episodes): -139.36
# Timestep: 56000, episode reward (moving average, 20 episodes): -138.37
# Timestep: 57000, episode reward (moving average, 20 episodes): -134.09
# Timestep: 58000, episode reward (moving average, 20 episodes): -145.63
# Timestep: 59000, episode reward (moving average, 20 episodes): -145.8
# Timestep: 60000, episode reward (moving average, 20 episodes): -136.5
# Timestep: 61000, episode reward (moving average, 20 episodes): -135.4
# Timestep: 62000, episode reward (moving average, 20 episodes): -128.36
# Timestep: 63000, episode reward (moving average, 20 episodes): -123.13
# Timestep: 64000, episode reward (moving average, 20 episodes): -118.68
# Timestep: 65000, episode reward (moving average, 20 episodes): -116.61
# Timestep: 66000, episode reward (moving average, 20 episodes): -116.92
# Timestep: 67000, episode reward (moving average, 20 episodes): -114.85
# Timestep: 68000, episode reward (moving average, 20 episodes): -113.37
# Timestep: 69000, episode reward (moving average, 20 episodes): -106.79
# Timestep: 70000, episode reward (moving average, 20 episodes): -100.8
# Timestep: 71000, episode reward (moving average, 20 episodes): -73.69
# Timestep: 72000, episode reward (moving average, 20 episodes): -72.67
# Timestep: 73000, episode reward (moving average, 20 episodes): -66.1
# Timestep: 74000, episode reward (moving average, 20 episodes): -98.63
# Timestep: 75000, episode reward (moving average, 20 episodes): -96.06
# Timestep: 76000, episode reward (moving average, 20 episodes): -96.56
# Timestep: 77000, episode reward (moving average, 20 episodes): -105.92
# ...
# Timestep: 76000, episode reward (moving average, 20 episodes): -169.36
# Timestep: 77000, episode reward (moving average, 20 episodes): -132.16
# Timestep: 78000, episode reward (moving average, 20 episodes): -138.87
# Timestep: 79000, episode reward (moving average, 20 episodes): -142.25
# Timestep: 80000, episode reward (moving average, 20 episodes): -155.38
# Timestep: 81000, episode reward (moving average, 20 episodes): -160.77
# Timestep: 82000, episode reward (moving average, 20 episodes): -166.75
# Timestep: 83000, episode reward (moving average, 20 episodes): -128.24
# Timestep: 84000, episode reward (moving average, 20 episodes): -124.57
# Timestep: 85000, episode reward (moving average, 20 episodes): -120.21
# Timestep: 86000, episode reward (moving average, 20 episodes): -120.51
# Timestep: 87000, episode reward (moving average, 20 episodes): -113.64
# Timestep: 88000, episode reward (moving average, 20 episodes): -113.54
# Timestep: 89000, episode reward (moving average, 20 episodes): -115.03
# Timestep: 90000, episode reward (moving average, 20 episodes): -118.45
# Timestep: 91000, episode reward (moving average, 20 episodes): -118.86
# Timestep: 92000, episode reward (moving average, 20 episodes): -121.68
# Timestep: 93000, episode reward (moving average, 20 episodes): -114.71
# Timestep: 94000, episode reward (moving average, 20 episodes): -119.21
# Timestep: 95000, episode reward (moving average, 20 episodes): -149.16
# Timestep: 96000, episode reward (moving average, 20 episodes): -135.75
# Timestep: 97000, episode reward (moving average, 20 episodes): -126.26
# Timestep: 98000, episode reward (moving average, 20 episodes): -120.31
# Timestep: 99000, episode reward (moving average, 20 episodes): -127.67
# Timestep: 100000, episode reward (moving average, 20 episodes): -135.39
# Timestep: 101000, episode reward (moving average, 20 episodes): -136.87
# Timestep: 102000, episode reward (moving average, 20 episodes): -135.56
# Timestep: 103000, episode reward (moving average, 20 episodes): -141.8
# Timestep: 104000, episode reward (moving average, 20 episodes): -131.05
# Timestep: 105000, episode reward (moving average, 20 episodes): -95.98
# Timestep: 106000, episode reward (moving average, 20 episodes): -85.44
# Timestep: 107000, episode reward (moving average, 20 episodes): -84.18
# Timestep: 108000, episode reward (moving average, 20 episodes): -95.98
# Timestep: 109000, episode reward (moving average, 20 episodes): -95.07
# Timestep: 110000, episode reward (moving average, 20 episodes): -96.26
# Timestep: 111000, episode reward (moving average, 20 episodes): -119.18
# Timestep: 112000, episode reward (moving average, 20 episodes): -137.28
# Timestep: 113000, episode reward (moving average, 20 episodes): -136.06
# Timestep: 114000, episode reward (moving average, 20 episodes): -132.41
# Timestep: 115000, episode reward (moving average, 20 episodes): -131.93
# Timestep: 116000, episode reward (moving average, 20 episodes): -130.22
# Timestep: 117000, episode reward (moving average, 20 episodes): -129.34
# Timestep: 118000, episode reward (moving average, 20 episodes): -117.84
# Timestep: 119000, episode reward (moving average, 20 episodes): -101.16
# Timestep: 120000, episode reward (moving average, 20 episodes): -97.8
# Timestep: 121000, episode reward (moving average, 20 episodes): -88.55
# Timestep: 122000, episode reward (moving average, 20 episodes): -61.59
# Timestep: 123000, episode reward (moving average, 20 episodes): -46.92
# Timestep: 124000, episode reward (moving average, 20 episodes): -28.62
# Timestep: 125000, episode reward (moving average, 20 episodes): -9.25
# Timestep: 126000, episode reward (moving average, 20 episodes): -16.73
# Timestep: 127000, episode reward (moving average, 20 episodes): -60.33
# Timestep: 128000, episode reward (moving average, 20 episodes): -110.02
# Timestep: 129000, episode reward (moving average, 20 episodes): -137.03
# Timestep: 130000, episode reward (moving average, 20 episodes): -161.97
# Timestep: 131000, episode reward (moving average, 20 episodes): -187.3
# Timestep: 132000, episode reward (moving average, 20 episodes): -197.99
# Timestep: 133000, episode reward (moving average, 20 episodes): -213.18
# Timestep: 134000, episode reward (moving average, 20 episodes): -214.39
# Timestep: 135000, episode reward (moving average, 20 episodes): -209.98
# Timestep: 136000, episode reward (moving average, 20 episodes): -190.37
# Timestep: 137000, episode reward (moving average, 20 episodes): -193.26
# Timestep: 138000, episode reward (moving average, 20 episodes): -162.2
# Timestep: 139000, episode reward (moving average, 20 episodes): -131.44
# Timestep: 140000, episode reward (moving average, 20 episodes): -119.61
# Timestep: 141000, episode reward (moving average, 20 episodes): -103.45
# Timestep: 142000, episode reward (moving average, 20 episodes): -92.52
# Timestep: 143000, episode reward (moving average, 20 episodes): -82.99
# Timestep: 144000, episode reward (moving average, 20 episodes): -53.5
# Timestep: 145000, episode reward (moving average, 20 episodes): -37.92
# Timestep: 146000, episode reward (moving average, 20 episodes): -33.15
# Timestep: 147000, episode reward (moving average, 20 episodes): -29.44
# Timestep: 148000, episode reward (moving average, 20 episodes): -63.8
# Timestep: 149000, episode reward (moving average, 20 episodes): -69.7
# Timestep: 150000, episode reward (moving average, 20 episodes): -113.23
# Timestep: 151000, episode reward (moving average, 20 episodes): -142.7
# Timestep: 152000, episode reward (moving average, 20 episodes): -147.56
# Timestep: 153000, episode reward (moving average, 20 episodes): -155.56
# Timestep: 154000, episode reward (moving average, 20 episodes): -155.65
# Timestep: 155000, episode reward (moving average, 20 episodes): -155.82
# Timestep: 156000, episode reward (moving average, 20 episodes): -151.06
# Timestep: 157000, episode reward (moving average, 20 episodes): -191.33
# Timestep: 158000, episode reward (moving average, 20 episodes): -211.17
# Timestep: 159000, episode reward (moving average, 20 episodes): -196.21
# Timestep: 160000, episode reward (moving average, 20 episodes): -191.88
# Timestep: 161000, episode reward (moving average, 20 episodes): -197.18
# Timestep: 162000, episode reward (moving average, 20 episodes): -208.73
# Timestep: 163000, episode reward (moving average, 20 episodes): -229.01
# Timestep: 164000, episode reward (moving average, 20 episodes): -226.02
# Timestep: 165000, episode reward (moving average, 20 episodes): -222.39
# Timestep: 166000, episode reward (moving average, 20 episodes): -221.29
# Timestep: 167000, episode reward (moving average, 20 episodes): -207.66
# Timestep: 168000, episode reward (moving average, 20 episodes): -183.41
# Timestep: 169000, episode reward (moving average, 20 episodes): -178.65
# Timestep: 170000, episode reward (moving average, 20 episodes): -176.03
# Timestep: 171000, episode reward (moving average, 20 episodes): -142.88
# Timestep: 172000, episode reward (moving average, 20 episodes): -140.34
# Timestep: 173000, episode reward (moving average, 20 episodes): -126.88
# Timestep: 174000, episode reward (moving average, 20 episodes): -136.37
# Timestep: 175000, episode reward (moving average, 20 episodes): -127.35
# Timestep: 176000, episode reward (moving average, 20 episodes): -133.84
# Timestep: 177000, episode reward (moving average, 20 episodes): -151.87
# Timestep: 178000, episode reward (moving average, 20 episodes): -156.97
# Timestep: 179000, episode reward (moving average, 20 episodes): -126.8
# Timestep: 180000, episode reward (moving average, 20 episodes): -118.51
# Timestep: 181000, episode reward (moving average, 20 episodes): -126.06
# Timestep: 182000, episode reward (moving average, 20 episodes): -102.69
# Timestep: 183000, episode reward (moving average, 20 episodes): -98.12
# Timestep: 184000, episode reward (moving average, 20 episodes): -95.27
# Timestep: 185000, episode reward (moving average, 20 episodes): -113.84
# Timestep: 186000, episode reward (moving average, 20 episodes): -103.15
# Timestep: 187000, episode reward (moving average, 20 episodes): -57.09
# Timestep: 188000, episode reward (moving average, 20 episodes): -56.94
# Timestep: 189000, episode reward (moving average, 20 episodes): -38.86
# Timestep: 190000, episode reward (moving average, 20 episodes): -33.76
# Timestep: 191000, episode reward (moving average, 20 episodes): -43.73
# Timestep: 192000, episode reward (moving average, 20 episodes): -34.04
# Timestep: 193000, episode reward (moving average, 20 episodes): -46.45
# Timestep: 194000, episode reward (moving average, 20 episodes): -18.32
# Timestep: 195000, episode reward (moving average, 20 episodes): -36.03
# Timestep: 196000, episode reward (moving average, 20 episodes): -37.87
# Timestep: 197000, episode reward (moving average, 20 episodes): -36.85
# Timestep: 198000, episode reward (moving average, 20 episodes): -34.14
# Timestep: 199000, episode reward (moving average, 20 episodes): -30.65
# Timestep: 200000, episode reward (moving average, 20 episodes): -3.42
# Timestep: 201000, episode reward (moving average, 20 episodes): 1.83
# Timestep: 202000, episode reward (moving average, 20 episodes): 5.26
# Timestep: 203000, episode reward (moving average, 20 episodes): -3.57
# Timestep: 204000, episode reward (moving average, 20 episodes): 25.79
# Timestep: 205000, episode reward (moving average, 20 episodes): 86.7
# Timestep: 206000, episode reward (moving average, 20 episodes): 125.95
# Timestep: 207000, episode reward (moving average, 20 episodes): 157.21
# Timestep: 208000, episode reward (moving average, 20 episodes): 201.0
# Timestep: 209000, episode reward (moving average, 20 episodes): 182.59
# Timestep: 210000, episode reward (moving average, 20 episodes): 156.03
# Timestep: 211000, episode reward (moving average, 20 episodes): 139.59
# Timestep: 212000, episode reward (moving average, 20 episodes): 134.87
# Timestep: 213000, episode reward (moving average, 20 episodes): 118.31
# Timestep: 214000, episode reward (moving average, 20 episodes): 141.35
# Timestep: 215000, episode reward (moving average, 20 episodes): 146.34
# Timestep: 216000, episode reward (moving average, 20 episodes): 151.19
# Timestep: 217000, episode reward (moving average, 20 episodes): 163.09
# Timestep: 218000, episode reward (moving average, 20 episodes): 122.78
# Timestep: 219000, episode reward (moving average, 20 episodes): 133.35
# Timestep: 220000, episode reward (moving average, 20 episodes): 119.45
# Timestep: 221000, episode reward (moving average, 20 episodes): 127.78
# Timestep: 222000, episode reward (moving average, 20 episodes): 142.19
# Timestep: 223000, episode reward (moving average, 20 episodes): 140.11
# Timestep: 224000, episode reward (moving average, 20 episodes): 154.55
# Timestep: 225000, episode reward (moving average, 20 episodes): 184.0
# Timestep: 226000, episode reward (moving average, 20 episodes): 205.37
# Timestep: 227000, episode reward (moving average, 20 episodes): 205.92
# Timestep: 228000, episode reward (moving average, 20 episodes): 228.65
# Timestep: 229000, episode reward (moving average, 20 episodes): 230.97
# Timestep: 230000, episode reward (moving average, 20 episodes): 252.27
# Timestep: 231000, episode reward (moving average, 20 episodes): 249.28
# Timestep: 232000, episode reward (moving average, 20 episodes): 237.47
# Timestep: 233000, episode reward (moving average, 20 episodes): 225.47
# Timestep: 234000, episode reward (moving average, 20 episodes): 203.14
# Timestep: 235000, episode reward (moving average, 20 episodes): 192.01
# Timestep: 236000, episode reward (moving average, 20 episodes): 77.83
# Timestep: 237000, episode reward (moving average, 20 episodes): 90.62
# Timestep: 238000, episode reward (moving average, 20 episodes): 97.06
# Timestep: 239000, episode reward (moving average, 20 episodes): 79.3
# Timestep: 240000, episode reward (moving average, 20 episodes): 92.2
# Timestep: 241000, episode reward (moving average, 20 episodes): 155.5
# Timestep: 242000, episode reward (moving average, 20 episodes): 141.31
# Timestep: 243000, episode reward (moving average, 20 episodes): 160.79
# Timestep: 244000, episode reward (moving average, 20 episodes): 158.98
# Timestep: 245000, episode reward (moving average, 20 episodes): 170.86
# Timestep: 246000, episode reward (moving average, 20 episodes): 82.86
# Timestep: 247000, episode reward (moving average, 20 episodes): 60.25
# Timestep: 248000, episode reward (moving average, 20 episodes): 63.1
# Timestep: 249000, episode reward (moving average, 20 episodes): 54.0
# Timestep: 250000, episode reward (moving average, 20 episodes): 44.48
# Timestep: 251000, episode reward (moving average, 20 episodes): 46.95
# Timestep: 252000, episode reward (moving average, 20 episodes): 29.66
# Timestep: 253000, episode reward (moving average, 20 episodes): 43.49
# Timestep: 254000, episode reward (moving average, 20 episodes): 67.46
# Timestep: 255000, episode reward (moving average, 20 episodes): 178.51
# Timestep: 256000, episode reward (moving average, 20 episodes): 197.26
# Timestep: 257000, episode reward (moving average, 20 episodes): 197.05
# Timestep: 258000, episode reward (moving average, 20 episodes): 186.09
# Timestep: 259000, episode reward (moving average, 20 episodes): 187.51
# Timestep: 260000, episode reward (moving average, 20 episodes): 170.1
# Timestep: 261000, episode reward (moving average, 20 episodes): 178.64
# Timestep: 262000, episode reward (moving average, 20 episodes): 176.62
# Timestep: 263000, episode reward (moving average, 20 episodes): 194.29
# Timestep: 264000, episode reward (moving average, 20 episodes): 230.19
# Timestep: 265000, episode reward (moving average, 20 episodes): 229.75
# Timestep: 266000, episode reward (moving average, 20 episodes): 246.85
# Timestep: 267000, episode reward (moving average, 20 episodes): 226.88
# Timestep: 268000, episode reward (moving average, 20 episodes): 218.36
# Timestep: 269000, episode reward (moving average, 20 episodes): 203.31
# Timestep: 270000, episode reward (moving average, 20 episodes): 206.05
# Timestep: 271000, episode reward (moving average, 20 episodes): 180.18
# Timestep: 272000, episode reward (moving average, 20 episodes): 190.09
# Timestep: 273000, episode reward (moving average, 20 episodes): 204.43
# Timestep: 274000, episode reward (moving average, 20 episodes): 205.82
# Timestep: 275000, episode reward (moving average, 20 episodes): 222.8
# Timestep: 276000, episode reward (moving average, 20 episodes): 202.63
# Timestep: 277000, episode reward (moving average, 20 episodes): 202.26
# Timestep: 278000, episode reward (moving average, 20 episodes): 194.09
# Timestep: 279000, episode reward (moving average, 20 episodes): 180.32
# Timestep: 280000, episode reward (moving average, 20 episodes): 184.71
# Timestep: 281000, episode reward (moving average, 20 episodes): 182.83
# Timestep: 282000, episode reward (moving average, 20 episodes): 178.07
# Timestep: 283000, episode reward (moving average, 20 episodes): 181.62
# Timestep: 284000, episode reward (moving average, 20 episodes): 167.75
# Timestep: 285000, episode reward (moving average, 20 episodes): 165.2
# Timestep: 286000, episode reward (moving average, 20 episodes): 184.02
# Timestep: 287000, episode reward (moving average, 20 episodes): 183.72
# Timestep: 288000, episode reward (moving average, 20 episodes): 199.65
# Timestep: 289000, episode reward (moving average, 20 episodes): 217.59
# Timestep: 290000, episode reward (moving average, 20 episodes): 226.83
# Timestep: 291000, episode reward (moving average, 20 episodes): 199.46
# Timestep: 292000, episode reward (moving average, 20 episodes): 178.12
# Timestep: 293000, episode reward (moving average, 20 episodes): 187.34
# Timestep: 294000, episode reward (moving average, 20 episodes): 187.37
# Timestep: 295000, episode reward (moving average, 20 episodes): 181.74
# Timestep: 296000, episode reward (moving average, 20 episodes): 176.18
# Timestep: 297000, episode reward (moving average, 20 episodes): 220.47
# Timestep: 298000, episode reward (moving average, 20 episodes): 237.47
# Timestep: 299000, episode reward (moving average, 20 episodes): 241.66
# Timestep: 300000, episode reward (moving average, 20 episodes): 243.42

# %%
colors = ['r', 'g', 'b', 'y', 'purple']
for i in range(5):
    agent = agents_hyper[i]
    color = colors[i]
    actor_lr, critic_lr = learning_rates[i]
    plt.plot(agent.list_moving_average_returns, color, label=f"with actor_lr = {actor_lr} and critic_lr = {critic_lr}")
plt.ylabel('Average Return (last 20 episodes)')
plt.xlabel('Episode#')
plt.title('Performance of the 5 Hyperparameters')
plt.ylim(-501, 300)
plt.legend()
plt.show()

# %% [markdown]
# #### Comments
#
# `A lower learning rate does not necessarily result in a more stable standard deviation;`
# `on the contrary, a higher learning rate can lead to faster convergence to the target.`
# `Due to the algorithm's randomness in the exploration process, the significance of a single training with a specific hyperparameter is limited.`

# %% [markdown]
# ## Point 1.4
#
# While applying RL in real world, you may consider the use of off-the-shelf implementation of RL algorithms. The package [Stable Baselines 3](stable-baselines3.readthedocs.io/) aims to provide a set of reliable implementations of RL algorithms in PyTorch.
#
# Familiarize yourself with this package and use its implementation of DDPG to learn the optimal policy for the Lunar Lander environment.

# %%
import gymnasium as gym
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy

class AverageEpisodeRewardsCallback(BaseCallback):
    """
    Stop the training once a maximum number of episodes are played.

    For multiple environments presumes that, the desired behavior is that the agent trains on each env for ``max_episodes``
    and in total for ``max_episodes * n_envs`` episodes.

    :param verbose: Verbosity level: 0 for no output, 1 for indicating information about when training ended by
        reaching ``max_episodes``
    """

    def __init__(
            self, 
            eval_env: gym.Env,
            n_eval_episodes: int = 20,
    ):
        super().__init__()

        self.eval_env = eval_env
        self.n_eval_episodes = n_eval_episodes

        self.n_episodes = 0
        self.rewards = []

    def _on_step(self) -> bool:
        # Check that the `dones` local variable is defined
        assert "dones" in self.locals, "`dones` variable is not defined, please check your code next to `callback.on_step()`"
        delta = np.sum(self.locals["dones"]).item()
        self.n_episodes += delta

        if delta > 0:
            mean_reward, std_reward = evaluate_policy(
                self.model,
                self.eval_env,
                n_eval_episodes=self.n_eval_episodes,
                return_episode_rewards=False,
            )
            self.rewards.append(mean_reward)

        continue_training = True
        return continue_training

# %% [markdown]
# ```yaml
# LunarLanderContinuous-v2:
#   n_timesteps: !!float 3e5
#   policy: 'MlpPolicy'
#   gamma: 0.98
#   buffer_size: 200000
#   learning_starts: 10000
#   noise_type: 'normal'
#   noise_std: 0.1
#   gradient_steps: -1
#   train_freq: [1, "episode"]
#   learning_rate: !!float 1e-3
#   policy_kwargs: "dict(net_arch=[400, 300])"
# ```

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import DDPG as sb3_DDPG
from stable_baselines3.common.noise import NormalActionNoise

env = gym.make("LunarLanderContinuous-v2")
n_actions = env.action_space.shape[0]

noise_std = 0.1
action_noise =  NormalActionNoise(
    mean=np.zeros(n_actions),
    sigma=noise_std * np.ones(n_actions),
)

model = sb3_DDPG(
    policy="MlpPolicy",
    env=env,
    gamma=0.98,
    buffer_size=200000,
    learning_starts=1000,
    action_noise=action_noise,
    gradient_steps=-1,
    train_freq=(1,"episode"),
    learning_rate=1e-3,
    policy_kwargs=dict(net_arch=[400, 300]),
)

callback = AverageEpisodeRewardsCallback(env)
model.learn(total_timesteps=int(3e5), log_interval=4, callback=callback)
# Out:
# /root/miniforge3/envs/torch/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
len(callback.rewards)
# Out:
# 884

# %% [markdown]
# In a single plot, compare the performance of your implementation of the algorithm in 1.1. with the one that you implemented above.

# %%
plt.plot(agent_001.list_moving_average_returns,'b',label="Ours")
plt.plot(callback.rewards,'r',label="Stable Baseline 3")
plt.ylabel('Average Return (last 20 episodes)')
plt.xlabel('Episode#')
plt.title('Performance during training')
plt.ylim(-501, 300)
plt.legend()
plt.show()

# %% [markdown]
# #### Comments
#
# `The optimal policy indeed proves to be more stable than our implementation, converging very rapidly and exhibiting less susceptibility to degradation.`
# `It took 3e5 timestamps to complete, whereas our implementation required 5e5 timestamps to achieve the same number of episodes.`
